# %% [markdown]
# # Facial Skincare Recommender System

# %% [markdown]
# ### Download Dataset from Kaggle

# %%
# import os
# import zipfile
# import pandas as pd

# # Download using Kaggle API
# os.system('kaggle datasets download -d nadyinky/sephora-products-and-skincare-reviews')

# # Unzip the downloaded dataset
# with zipfile.ZipFile('sephora-products-and-skincare-reviews.zip', 'r') as zip_ref:
#     zip_ref.extractall('sephora_dataset')

# # Load product information
# products_df = pd.read_csv("sephora_dataset/product_info.csv")

# print(products_df.head()) # for checking purpose

# %%
import pandas as pd

products_df = pd.read_csv('data/OriDataset/product_info.csv')

# %% [markdown]
# ### Filter Skincare Product only in primary_category, secondary_category, and tertiary_category columns
# (remove makeup, fragrance, bath&body, hair, teeth, supplement, etc products)

# %%
# Convert product_id to string and strip whitespace
products_df['product_id'] = products_df['product_id'].astype(str).str.strip()

# Filter only 'Skincare' at primary_category 
skincare_products_df = products_df[products_df['primary_category'].str.lower() == 'skincare'].copy()

# Keep only specific secondary categories
allowed_secondary_categories = [
    'Moisturizers', 'Treatments', 'Eye Care', 'Lip Balms & Treatments',
    'Sunscreen', 'Cleansers', 'Masks'
]

skincare_products_df = skincare_products_df[skincare_products_df['secondary_category'].isin(allowed_secondary_categories)].copy()

# Keep only selected tertiary categories
allowed_tertiary_categories = [
    'Moisturizers', 'Face Serums', 'Eye Creams & Treatments', 'Face Sunscreen',
    'Face Wash & Cleansers', 'Face Oils', 'Toners', 'Face Masks', 'Facial Peels',
    'Exfoliators', 'Eye Masks', 'Face Wipes', 'Blemish & Acne Treatments',
    'Night Creams', 'Mists & Essences', 'Sheet Masks', 'Makeup Removers'
]

skincare_products_df = skincare_products_df[skincare_products_df['tertiary_category'].isin(allowed_tertiary_categories)].copy()

# Save to new CSV file
skincare_products_df.to_csv("data/CleanedDataSet/filtered_skincare_products.csv", index=False)
print("Filtered products dataset saved as 'filtered_skincare_products.csv'")
# Out:
# Filtered products dataset saved as 'filtered_skincare_products.csv'

# %% [markdown]
# ### Filter Reviews to Keep only Skincare Review

# %%
# Load filtered skincare products IDs
filtered_products = pd.read_csv("data/CleanedDataSet/filtered_skincare_products.csv")
skincare_product_ids = set(filtered_products['product_id'].unique())

import glob

# List of file paths
review_files = [
    "data/OriDataSet/reviews_0-250.csv",
    "data/OriDataSet/reviews_250-500.csv",
    "data/OriDataSet/reviews_500-750.csv",
    "data/OriDataSet/reviews_750-1250.csv",
    "data/OriDataSet/reviews_1250-end.csv"
]

# Initialize empty list to store filtered reviews
all_filtered_reviews = []

for file in review_files:
    reviews_df = pd.read_csv(file)
    
    skincare_reviews = reviews_df[reviews_df['product_id'].isin(skincare_product_ids)].copy()
    all_filtered_reviews.append(skincare_reviews)

# Merge all and save as one new file
merged_reviews_df = pd.concat(all_filtered_reviews, ignore_index=True)

# Add sequential review_id
merged_reviews_df['review_id'] = merged_reviews_df.index + 1

# Drop essential missing values
merged_reviews_df.dropna(subset=["author_id", "product_id", "rating", "review_text", "skin_type"], inplace=True)

# Keep valid ratings
merged_reviews_df = merged_reviews_df[(merged_reviews_df["rating"] >= 1) & (merged_reviews_df["rating"] <= 5)]

# Remove duplicates
merged_reviews_df.drop_duplicates(inplace=True)

merged_reviews_df.to_csv("data/CleanedDataSet/filtered_skincare_reviews.csv", index=False)

print(f"\nFinal merged reviews file saved as: filtered_skincare_reviews.csv")
print(f"Total reviews: {len(merged_reviews_df)}")
# Out:
# C:\Users\lucas\AppData\Local\Temp\ipykernel_36452\3593967287.py:20: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   reviews_df = pd.read_csv(file)
# C:\Users\lucas\AppData\Local\Temp\ipykernel_36452\3593967287.py:20: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   reviews_df = pd.read_csv(file)
# C:\Users\lucas\AppData\Local\Temp\ipykernel_36452\3593967287.py:20: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   reviews_df = pd.read_csv(file)
# Final merged reviews file saved as: filtered_skincare_reviews.csv
# Total reviews: 801455

# %% [markdown]
# ## Data Understanding

# %% [markdown]
# #### Number of Record with Tertiary Category

# %%
import matplotlib.pyplot as plt

# Display value counts and total count for secondary_category
secondary_counts = skincare_products_df['secondary_category'].value_counts()
total_secondary = secondary_counts.sum()

print("Secondary Category Counts:\n")
print(secondary_counts)
print("\nTotal number of records with secondary category:", total_secondary)
# Out:
# Secondary Category Counts:
#
# secondary_category
# Moisturizers    536
# Treatments      466
# Cleansers       354
# Eye Care        186
# Masks           166
# Sunscreen        95
# Name: count, dtype: int64
#
# Total number of records with secondary category: 1803

# %% [markdown]
# #### Number of Record with Tertiary Category

# %%
# Display value counts and total count in one cell
tertiary_counts = skincare_products_df['tertiary_category'].value_counts()
total_count = tertiary_counts.sum()

print("Tertiary Category Counts:\n")
print(tertiary_counts)
print("\nTotal number of records with tertiary category:", total_count)
# Out:
# Tertiary Category Counts:
#
# tertiary_category
# Moisturizers                 386
# Face Serums                  379
# Face Wash & Cleansers        217
# Eye Creams & Treatments      172
# Face Masks                   134
# Face Sunscreen                95
# Toners                        80
# Mists & Essences              67
# Face Oils                     66
# Facial Peels                  50
# Exfoliators                   41
# Blemish & Acne Treatments     37
# Sheet Masks                   32
# Night Creams                  17
# Eye Masks                     14
# Makeup Removers               10
# Face Wipes                     6
# Name: count, dtype: int64
#
# Total number of records with tertiary category: 1803

# %% [markdown]
# #### Count Review Based on Product Id

# %%
review_counts = merged_reviews_df.groupby('product_id').size().reset_index(name='review_count')
total_review = review_counts['review_count'].sum()

# Display the result
print(review_counts)
print(total_review)
# Out:
#      product_id  review_count
# 0       P107306           200
# 1       P114902           914
# 2        P12045          1148
# 3       P122651           159
# 4       P122661           456
# ...         ...           ...
# 1760     P94421          2523
# 1761     P94812           395
# 1762      P9939           207
# 1763      P9940           730
# 1764      P9941           325
#
# [1765 rows x 2 columns]
# 801455

# %% [markdown]
# #### Count Number of Review based on the Product Categry

# %%
merged_data = review_counts.merge(skincare_products_df[['product_id', 'secondary_category', 'tertiary_category']], 
                                 on='product_id', 
                                 how='left')

# Count reviews by secondary_category
secondary_counts = merged_data.groupby('secondary_category')['review_count'].sum().reset_index(name='review_count')

#  Count reviews by tertiary_category
tertiary_counts = merged_data.groupby('tertiary_category')['review_count'].sum().reset_index(name='review_count')

# Calculate total reviews for each category
total_reviews_secondary = secondary_counts['review_count'].sum()
total_reviews_tertiary = tertiary_counts['review_count'].sum()

# Display the results with totals
print("Review Counts by Secondary Category:")
print(secondary_counts)
print(f"\nTotal Reviews (Secondary Category): {total_reviews_secondary}")

print("\nReview Counts by Tertiary Category:")
print(tertiary_counts)
print(f"\nTotal Reviews (Tertiary Category): {total_reviews_tertiary}")
# Out:
# Review Counts by Secondary Category:
#   secondary_category  review_count
# 0          Cleansers        177165
# 1           Eye Care         69496
# 2              Masks         56683
# 3       Moisturizers        254676
# 4          Sunscreen         37605
# 5         Treatments        205830
#
# Total Reviews (Secondary Category): 801455
#
# Review Counts by Tertiary Category:
#             tertiary_category  review_count
# 0   Blemish & Acne Treatments         16091
# 1                 Exfoliators         21631
# 2     Eye Creams & Treatments         65475
# 3                   Eye Masks          4021
# 4                  Face Masks         53784
# 5                   Face Oils         30307
# 6                 Face Serums        166605
# 7              Face Sunscreen         37605
# 8       Face Wash & Cleansers        108802
# 9                  Face Wipes          3680
# 10               Facial Peels         23134
# 11            Makeup Removers          9847
# 12           Mists & Essences         27130
# 13               Moisturizers        190385
# 14               Night Creams          6854
# 15                Sheet Masks          2899
# 16                     Toners         33205
#
# Total Reviews (Tertiary Category): 801455

# %%
merged_reviews_df.head()
# Out:
#    Unnamed: 0    author_id  rating  is_recommended  helpfulness  \
# 1       16140  31124221503       5             1.0          1.0
# 2       16141  20246074916       5             1.0          1.0
# 3       16142   5182718480       1             0.0          0.0
# 5       16144  27905619860       5             1.0          1.0
# 6       16145   8523204146       3             0.0          0.0
#
#    total_feedback_count  total_neg_feedback_count  total_pos_feedback_count  \
# 1                     1                         0                         1
# 2                     2                         0                         2
# 3                     2                         2                         0
# 5                     2                         0                         2
# 6                     1                         1                         0
#
#   submission_time                                        review_text  \
# 1      2023-03-19  Makeup remover, gentle cleanser, and all aroun...
# 2      2023-03-15  I have been using this for almost 10 years. Lo...
# 3      2023-03-10  I wanted to love this so bad because it felt s...
# 5      2023-03-09  Best facial cleanser I have used! I heard grea...
# 6      2023-03-06  I found this to be just ok - definitely gentle...
#
#                             review_title  skin_tone eye_color    skin_type  \
# 1                  Best. Cleanser. Ever.       fair     brown  combination
# 2  The cleanser I have used for 10 years        NaN     hazel  combination
# 3                                    NaN  mediumTan     brown  combination
# 5               Hands down best cleanser      light     hazel  combination
# 6                                    NaN      light     hazel  combination
#
#   hair_color product_id                        product_name brand_name  \
# 1     blonde      P7880  Soy Hydrating Gentle Face Cleanser      fresh
# 2        NaN      P7880  Soy Hydrating Gentle Face Cleanser      fresh
# 3      brown      P7880  Soy Hydrating Gentle Face Cleanser      fresh
# 5      brown      P7880  Soy Hydrating Gentle Face Cleanser      fresh
# 6        NaN      P7880  Soy Hydrating Gentle Face Cleanser      fresh
#
#    price_usd  review_id
# 1       39.0          2
# 2       39.0          3
# 3       39.0          4
# 5       39.0          6
# 6       39.0          7

# %%
merged_reviews_df.shape
# Out:
# (801455, 20)

# %% [markdown]
# ##### Grouping Review by product_id + Calculating Rating's Means + Viewing Ratings

# %%
merged_reviews_df.groupby('product_id')['rating'].mean()
# Out:
# product_id
# P107306    4.040000
# P114902    4.431072
# P12045     4.451220
# P122651    4.509434
# P122661    4.506579
#              ...
# P94421     4.258423
# P94812     4.620253
# P9939      4.265700
# P9940      4.312329
# P9941      4.507692
# Name: rating, Length: 1765, dtype: float64

# %% [markdown]
# ##### Grouping Review by product_id + Viewing Rating in Descending Order

# %%
merged_reviews_df.groupby('product_id').agg(rating = ('rating', 'mean'), vote = ('rating', 'sum')).sort_values(by = 'vote', ascending = False)
# Out:
#               rating   vote
# product_id
# P7880       4.368198  28817
# P394639     4.491649  28239
# P269122     4.545455  26750
# P450271     4.491100  26493
# P417238     4.491100  26493
# ...              ...    ...
# P501175     5.000000      5
# P475083     4.000000      4
# P483086     4.000000      4
# P481993     3.000000      3
# P480441     3.000000      3
#
# [1765 rows x 2 columns]

# %% [markdown]
# ##### Grouping Review by brand_name + Viewing Rating in Descending Order

# %%
merged_reviews_df.groupby('brand_name').agg(rating = ('rating', 'mean'), vote = ('rating', 'sum')).sort_values(by = 'vote', ascending = False)
# Out:
#                            rating    vote
# brand_name
# The Ordinary             4.215004  148836
# Drunk Elephant           4.081731  146277
# CLINIQUE                 4.225071  142537
# Tatcha                   4.281871  130049
# fresh                    4.434038  114478
# ...                           ...     ...
# Anastasia Beverly Hills  4.555556     123
# Soleil Toujours          4.434783     102
# The Nue Co.              5.000000      80
# Isle of Paradise         3.040000      76
# Jack Black               3.500000      42
#
# [124 rows x 2 columns]

# %% [markdown]
# ## Data Preprocessing

# %%
import re
import ast
import unicodedata
import pandas as pd

# Input and output file paths
IN_PATH  = "data/CleanedDataSet/filtered_skincare_products.csv"   # raw filtered file
OUT_PATH = "data/CleanedDataSet/products_preprocessed.csv"        # final preprocessed file
SHOW_DEBUG = True

# ------------------------------
# Basic helpers
# ------------------------------
def norm_text(s):
    # Normalize text: lowercase, strip, collapse whitespace
    if not isinstance(s, str):
        s = "" if pd.isna(s) else str(s)
    return re.sub(r"\s+", " ", s.lower().strip())

def map_with_table(text, table):
    # Match text against regex patterns in a table, return first label found
    if not text:
        return None
    for patt, label in table:
        if re.search(patt, text, flags=re.IGNORECASE):
            return label
    return None

# ------------------------------
# Product-type rules 
# ------------------------------
# Map regex patterns from categories/names to standardized product types
TERTIARY_MAP = [
    (r"\beye (creams?(\s*&\s*treatments?)?|masks?|care)\b", "eye treatment"),
    (r"\bface serums?\b", "serum"),
    (r"\bserums?\b", "serum"),
    (r"\bface oils?\b|\bfacial oils?\b", "face oil"),
    (r"\bface sunscreen\b|\bsunscreens?\b|\bsun care\b|\bspf\b", "sunscreen"),
    (r"\bmoisturizers?\b|\bnight creams?\b|\bgel[- ]?creams?\b|\bface creams?\b|\blotions?\b|\bemulsions?\b", "moisturizer"),
    (r"\bface masks?\b|\bsheet masks?\b|\bsleeping masks?\b|\bovernight masks?\b|\bclay masks?\b|\bmud masks?\b", "face mask"),
    (r"\bface wipes\b|\bmakeup removers?\b", "makeup remover"),
    (r"\bcleansers?\b|\bface wash\b|\bmicellar\b", "cleanser"),
    (r"\btoners?\b|\bmists? & essences?\b|\bessences?\b", "toner"),
    (r"\bblemish\s*&\s*acne treatments?\b|\bspot (treatments?|correctors?)\b|\bacne spot\b", "spot treatment"),
    (r"\bexfoliators?\b|\bexfoliants?\b|\bpeels?\b|\bscrubs?\b|\b(aha|bha|pha)\b", "exfoliator"),
]
SECONDARY_MAP = TERTIARY_MAP  # Reuse same mapping for secondary

# Fallback rules if product type not found in categories
NAME_RULES = [
    (r"\beye (cream|serum|gel|balm|mask|treatment)\b", "eye treatment"),
    (r"\bface oil|facial oil|night oil|firming oil\b|\boil\b(?!\s*cleanser)", "face oil"),
    (r"\bface wipes\b|\bmakeup remover\b", "makeup remover"),
    (r"\b(cleanser|cleansing|face wash|micellar|balm cleanser|oil cleanser)\b", "cleanser"),
    (r"\b(toner|tonique)\b|\bmists?\b|\bessence\b(?!\s*serum)", "toner"),
    (r"\b(serum|ampoule|booster)\b(?!\s*mask)|\bessence serum\b", "serum"),
    (r"\b(sunscreen|sun screen|spf)\b", "sunscreen"),
    (r"\b(mask|sheet mask|sleeping mask|wash[- ]?off mask|overnight mask|mud mask|clay mask)\b", "face mask"),
    (r"\b(spot (treatment|corrector)|acne spot|blemish treatment)\b", "spot treatment"),
    (r"\b(exfoliator|exfoliant|peel|aha|bha|pha|scrub)\b", "exfoliator"),
    (r"\b(moisturizer|moisturiser|cream|lotion|emulsion|gel[- ]?cream|face cream)\b", "moisturizer"),
]

def detect_product_type(row):
    # Infer product type from tertiary > secondary > name (priority order)
    name = norm_text(row.get("product_name", ""))
    sec  = norm_text(row.get("secondary_category", ""))
    ter  = norm_text(row.get("tertiary_category", ""))

    # Tertiary category first
    label = map_with_table(ter, TERTIARY_MAP)
    if label: return label

    # Secondary (skip if too generic like 'treatment')
    is_generic = bool(re.fullmatch(r"(treatment|treatments)", sec.strip()))
    if not is_generic:
        label = map_with_table(sec, SECONDARY_MAP)
        if label: return label

    # Fallback: check product name
    label = map_with_table(name, NAME_RULES)
    if label: return label

    return "other"

# ------------------------------
# Skin type + concern rules 
# ------------------------------
# Regex patterns to detect skin types from text
SKIN_TYPE_PATTERNS = [
    (r"\b(?:good|best)\s*for:\s*oily\b", "oily"),
    (r"\b(?:good|best)\s*for:\s*dry\b", "dry"),
    (r"\b(?:good|best)\s*for:\s*combination\b", "combination"),
    (r"\b(?:good|best)\s*for:\s*sensitive\b", "sensitive"),
    (r"\b(?:good|best)\s*for:\s*normal\b", "normal"),
    (r"\b(oily skin|oily)\b", "oily"),
    (r"\b(dry skin|dry)\b", "dry"),
    (r"\b(combination skin|combination|combo)\b", "combination"),
    (r"\b(sensitive skin|sensitive)\b", "sensitive"),
    (r"\b(normal skin|normal)\b", "normal"),
    (r"\bfor\s+sensitive\s+skin\b", "sensitive"),
    (r"\bsuitable\s+for\s+sensitive\b", "sensitive"),
    (r"\bfor\s+sensitive\b", "sensitive"),
    (r"\bhypoallergenic\b", "sensitive"),
    (r"\bgentle\b", "sensitive"),
]

# Regex patterns to detect skin concerns from claims or product name
SKIN_CONCERN_PATTERNS = [
    (r"\b(acne|blemish|breakout|pimple)\b", "acne"),
    (r"\bpores?\b", "pores"),
    (r"\b(dark spot|hyperpigment|discoloration|melasma)\b", "hyperpigmentation"),
    (r"\b(wrinkle|fine line|anti[- ]?aging|firming|loss of firmness|elasticity)\b", "aging"),
    (r"\b(redness|rosacea|irritation|calming|soothing)\b", "redness"),
    (r"\b(dryness|dehydration|hydrating|moisturizing|moisturising|barrier)\b", "dehydration"),
    (r"\b(dull(ness)?|brighten(ing)?|glow|radiance)\b", "dullness"),
    (r"\boil(y| control|iness)\b", "oil-control"),
    (r"\b(blackhead|whitehead|congestion)\b", "blackheads"),
    (r"\b(uneven (tone|texture)|texture|resurfacing)\b", "texture"),
    (r"\b(dark circle|dark circles)\b", "dark-circles"),
]

# Ingredient-based concern mapping
INGREDIENT_CONCERN_PATTERNS = [
    (r"\b(salicylic acid|beta hydroxy|bha|willow bark|benzoyl peroxide|sulfur|zinc pca|zinc)\b", {"acne","pores","oil-control"}),
    (r"\b(kaolin|bentonite|clay|charcoal)\b", {"pores","oil-control"}),
    (r"\b(tea tree|melaleuca)\b", {"acne"}),
    (r"\b(hyaluronic acid|sodium hyaluronate|glycerin|panthenol|urea|betaine|trehalose|aloe)\b", {"dehydration"}),
    (r"\b(ceramide|ceramides|cholesterol|squalane|squalene|shea|shea butter)\b", {"dehydration"}),
    (r"\b(retinol|retinal|retinoate|bakuchiol|peptide|matrixyl|collagen|coenzyme ?q10|ubiquinone)\b", {"aging"}),
    (r"\b(vitamin ?c|ascorbic|ascorbyl|ethyl ascorbic|magnesium ascorbyl|sodium ascorbyl|alpha arbutin|tranexamic|azelaic|kojic|licorice|glycyrrhiza)\b", {"hyperpigmentation","dullness"}),
    (r"\b(centella|cica|madecassoside|asiaticoside|allantoin|bisabolol|beta glucan|green tea|oat|colloidal oatmeal)\b", {"redness"}),
    (r"\b(aha|glycolic|lactic|mandelic|tartaric|citric|pha|gluconolactone|lactobionic)\b", {"texture","dullness"}),
]

def to_list_from_highlights(val):
    # Parse highlights column into list (safe eval or regex split)
    if pd.isna(val):
        return []
    s = str(val).strip()
    try:
        parsed = ast.literal_eval(s)
        if isinstance(parsed, list):
            return [str(x) for x in parsed]
    except Exception:
        pass
    return [t.strip() for t in re.split(r"[,\|;/]+", s) if t.strip()]

def extract_skin_types_from_highlights_and_name(highlights_list, product_name):
    # Detect skin types from highlights + product name
    stypes = set()
    for raw in highlights_list:
        t = norm_text(raw)
        for patt, lab in SKIN_TYPE_PATTERNS:
            if re.search(patt, t):
                stypes.add(lab)
    pname = norm_text(product_name)
    if re.search(r"\bsensitive\b", pname):
        stypes.add("sensitive")
    return ",".join(sorted(stypes))

def extract_concerns_from_highlights_and_name(highlights_list, product_name):
    # Detect skin concerns from highlights + product name
    concerns = set()
    for raw in highlights_list:
        t = norm_text(raw)
        for patt, lab in SKIN_CONCERN_PATTERNS:
            if re.search(patt, t):
                concerns.add(lab)
    pname = norm_text(product_name)
    for patt, lab in SKIN_CONCERN_PATTERNS:
        if re.search(patt, pname):
            concerns.add(lab)
    return concerns

def extract_concerns_from_ingredients(ingredients_text):
    # Detect skin concerns directly from ingredient list
    concerns = set()
    ing = norm_text(ingredients_text)
    for patt, labs in INGREDIENT_CONCERN_PATTERNS:
        if re.search(patt, ing):
            concerns |= labs
    return concerns

# ------------------------------
# Text cleaning for vectorization
# ------------------------------

STOPWORDS = {
    "a","an","the","and","or","but","to","of","for","on","in","into","with","by","from","as",
    "it","its","this","that","these","those","is","are","was","were","be","been","being",
    "at","up","down","over","under","about","than","then","so","such","very","more","most",
    "less","least","you","your","yours","we","our","ours","they","their","theirs","he","she","his","her","them","i","me","my","mine"
}

PHRASES = [
    (r"\bhyaluronic acid\b", "hyaluronic_acid"),
    (r"\bsodium hyaluronate\b", "sodium_hyaluronate"),
    (r"\bsalicylic acid\b", "salicylic_acid"),
    (r"\bbenzoyl peroxide\b", "benzoyl_peroxide"),
    (r"\balpha hydroxy\b", "alpha_hydroxy"),
    (r"\bbeta hydroxy\b", "beta_hydroxy"),
    (r"\bpolyhydroxy\b", "polyhydroxy"),
    (r"\bvitamin c\b", "vitamin_c"),
    (r"\bvitamin e\b", "vitamin_e"),
    (r"\bcoenzyme q10\b|\bubiquinone\b", "coenzyme_q10"),
    (r"\btea tree\b", "tea_tree"),
    (r"\bcentella asiatica\b|\bcica\b", "centella_asiatica"),
    (r"\bgreen tea\b", "green_tea"),
    (r"\bniacinamide\b", "niacinamide"),
    (r"\bretino(l|id|ate|nal)\b", "retinoid"),
    (r"\baha\b", "aha"),
    (r"\bbha\b", "bha"),
    (r"\bpha\b", "pha"),
    (r"\bspf\s*\d+\b", lambda m: "spf_" + re.sub(r"\D", "", m.group(0))),
]

def deaccent(s):
    # Remove accents/diacritics from text 
    return unicodedata.normalize("NFKD", s).encode("ascii", "ignore").decode("ascii")

def strip_html(s):
    # Remove HTML tags
    return re.sub(r"<[^>]+>", " ", s)

def basic_normalize(s):
    # General normalization: lowercase, strip HTML, remove symbols/numbers
    if not isinstance(s, str):
        s = "" if pd.isna(s) else str(s)
    s = s.lower()
    s = strip_html(s)
    s = deaccent(s)
    s = re.sub(r"[\/\+]", " ", s)                # split slashes/plus
    s = re.sub(r"[^a-z0-9\-\_\s]", " ", s)       # keep hyphen/underscore
    s = re.sub(r"\b\d+\b", " ", s)               # drop standalone numbers
    s = re.sub(r"\s+", " ", s).strip()
    return s

def apply_phrases(s):
    # Replace key phrases with normalized tokens
    for patt, repl in PHRASES:
        s = re.sub(patt, repl if isinstance(repl, str) else repl, s, flags=re.IGNORECASE)
    return s

def clean_text(s):
    # Full text cleaning pipeline for vectorization
    s = "" if s is None else str(s)
    s = apply_phrases(s)
    s = basic_normalize(s)
    toks = s.split()
    toks = [t for t in toks if (t not in STOPWORDS and len(t) > 1)]
    # Remove duplicates while keeping word order
    seen, out = set(), []
    for t in toks:
        if t not in seen:
            out.append(t); seen.add(t)
    return " ".join(out)

# ------------------------------
# Build combined content
# ------------------------------
def combine_categories(row):
    # Combine primary + secondary + tertiary categories into one string
    parts = [
        str(row.get("primary_category", "") or ""),
        str(row.get("secondary_category", "") or ""),
        str(row.get("tertiary_category", "") or "")
    ]
    return " ".join([p for p in parts if p]).strip()

def parse_highlights_text(val):
    # Convert highlights list into plain text string
    lst = to_list_from_highlights(val)
    return " ".join(lst)

def build_product_content(row):
    # Build final product_content field with weighted chunks
    chunks = [
        row.get("clean_product_name", ""),
        row.get("clean_brand_name", ""),
        row.get("clean_categories", ""),
        row.get("clean_highlights", ""),
        row.get("clean_ingredients", ""),
        row.get("clean_product_type", ""),
        row.get("clean_skin_type", ""),
        row.get("clean_skin_concern", ""),
    ]

    # Weight ingredients higher (add twice more)
    ingredients = row.get("clean_ingredients", "")
    chunks += [ingredients] * 2

    return " ".join([c for c in chunks if c]).strip()

# ------------------------------
# Main pipeline
# ------------------------------
def main():
    # Load dataset
    df = pd.read_csv(IN_PATH, encoding="utf-8")

    # Defensive defaults: ensure required columns exist
    for c in ["product_id","product_name","brand_name","ingredients","highlights",
              "primary_category","secondary_category","tertiary_category","price_usd", "rating", "reviews"]:
        if c not in df.columns:
            df[c] = ""

    # (A) RULE-BASED ENRICHMENT 
    df["product_type"] = df.apply(detect_product_type, axis=1)  # infer product type
    df["_highlights_list"] = df["highlights"].apply(to_list_from_highlights)  # parse highlights
    df["skin_type"] = df.apply(  # infer skin type
        lambda r: extract_skin_types_from_highlights_and_name(r["_highlights_list"], r["product_name"]),
        axis=1
    )
    df["ingredients"] = df["ingredients"].fillna("").astype(str)  # ensure string ingredients

    # Skin concern = union of claims/name + ingredients
    concerns_from_claims = df.apply(
        lambda r: extract_concerns_from_highlights_and_name(r["_highlights_list"], r["product_name"]),
        axis=1
    )
    concerns_from_ings = df["ingredients"].apply(extract_concerns_from_ingredients)
    df["skin_concern"] = [
        ",".join(sorted(set(a) | set(b)))
        for a, b in zip(concerns_from_claims, concerns_from_ings)
    ]

    # Convert price to numeric
    df["price_usd"] = pd.to_numeric(df["price_usd"], errors="coerce")

    df["rating"] = pd.to_numeric(df.get("rating"), errors="coerce")
    df["reviews"] = pd.to_numeric(df.get("reviews"), errors="coerce")

    # (B) TEXT CLEANING + CONTENT 
    df["_categories_raw"] = df.apply(combine_categories, axis=1)
    df["_highlights_text"] = df["highlights"].apply(parse_highlights_text)

    # Clean text fields
    df["clean_product_name"] = df["product_name"].apply(clean_text)
    df["clean_brand_name"]   = df["brand_name"].apply(clean_text)
    df["clean_categories"]   = df["_categories_raw"].apply(clean_text)
    df["clean_highlights"]   = df["_highlights_text"].apply(clean_text)
    df["clean_ingredients"]  = df["ingredients"].apply(clean_text)
    df["clean_product_type"] = df["product_type"].apply(clean_text)
    df["clean_skin_type"]    = df["skin_type"].apply(clean_text)
    df["clean_skin_concern"] = df["skin_concern"].apply(clean_text)

    # Build final product_content field (for TF-IDF)
    df["product_content"] = df.apply(build_product_content, axis=1)

    # Save final
    keep_cols = [
        "product_id","product_name","brand_name","ingredients","highlights",
        "primary_category","secondary_category","tertiary_category","price_usd", "rating", "reviews", 
        "product_type","skin_type","skin_concern","product_content"
    ]
    for c in keep_cols:
        if c not in df.columns:
            df[c] = ""
    df[keep_cols].to_csv(OUT_PATH, index=False)

    # Debug sample output
    if SHOW_DEBUG:
        print(f"Final products preprocessed file saved as: {OUT_PATH}")
        print("Sample product_content:")
        print(df["product_content"].head(5).to_string(index=False))

if __name__ == "__main__":
    main()
# Out:
# Final products preprocessed file saved as: data/CleanedDataSet/products_preprocessed.csv
# Sample product_content:
# genius sleeping collagen moisturizer algenist s...
# genius liquid collagen serum algenist skincare ...
# triple algae eye renewal balm cream algenist sk...
# sublime defense ultra lightweight uv fluid spf_...
# genius ultimate anti-aging cream algenist skinc...

# %% [markdown]
# ### Merging Reciew and Product DataFrames Together based on product_id

# %%
reviews_df = merged_reviews_df[['author_id', 'product_id', 'product_name', 'brand_name','rating', 'skin_type']]

df_review = reviews_df.merge(skincare_products_df[['product_id', 'price_usd', 'secondary_category', 'tertiary_category']], 
                            on='product_id', how='left')
print(df_review.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 801455 entries, 0 to 801454
# Data columns (total 9 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   author_id           801455 non-null  object
#  1   product_id          801455 non-null  object
#  2   product_name        801455 non-null  object
#  3   brand_name          801455 non-null  object
#  4   rating              801455 non-null  int64
#  5   skin_type           801455 non-null  object
#  6   price_usd           801455 non-null  float64
#  7   secondary_category  801455 non-null  object
#  8   tertiary_category   801455 non-null  object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 55.0+ MB
# None

# %%
print(f"Unique users: {df_review['author_id'].nunique()}, Unique products: {df_review['product_id'].nunique()}")
# Out:
# Unique users: 455845, Unique products: 1765

# %% [markdown]
# Duplicated Row

# %%
merged_reviews_df.duplicated().sum()
# Out:
# 0

# %%
df_review.duplicated().sum()
# Out:
# 1838

# %%
df_review = df_review.drop_duplicates(subset=['author_id', 'product_id'], keep='last')
df_review.shape
# Out:
# (798983, 9)

# %% [markdown]
# Missing Value

# %%
df_review.isnull().sum()
# Out:
# author_id             0
# product_id            0
# product_name          0
# brand_name            0
# rating                0
# skin_type             0
# price_usd             0
# secondary_category    0
# tertiary_category     0
# dtype: int64

# %% [markdown]
# Convert to lovercase and replace unknown to the missing value

# %%
df_review['skin_type'] = df_review['skin_type'].str.lower().fillna('unknown')

# %% [markdown]
# # Modeling

# %% [markdown]
# ## Content-Based Filtering - Yap Zi Wen

# %% [markdown]
# ### TF-IDF Vectorizer

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

# Load preprocessed data
df = pd.read_csv("data/CleanedDataSet/products_preprocessed.csv")

# TF-IDF vectorization
vectorizer = TfidfVectorizer(stop_words='english')
tfidf_matrix = vectorizer.fit_transform(df['product_content'])

# for checking purpose
print(df[['product_name', 'product_content']].head())
print("TF-IDF shape: " + str(tfidf_matrix.shape))
print("Feature names: " + str(vectorizer.get_feature_names_out()[:50]))
# Out:
#                                         product_name  \
# 0               GENIUS Sleeping Collagen Moisturizer
# 1                       GENIUS Liquid Collagen Serum
# 2            Triple Algae Eye Renewal Balm Eye Cream
# 3  SUBLIME DEFENSE Ultra Lightweight UV Defense F...
# 4                   GENIUS Ultimate Anti-Aging Cream
#
#                                      product_content
# 0  genius sleeping collagen moisturizer algenist ...
# 1  genius liquid collagen serum algenist skincare...
# 2  triple algae eye renewal balm cream algenist s...
# 3  sublime defense ultra lightweight uv fluid spf...
# 4  genius ultimate anti-aging cream algenist skin...
# TF-IDF shape: (1803, 4872)
# Feature names: ['100h' '10eicosanedioate' '14m' '15ml' '1st' '20k' '24k' '25th' '360o'
#  '3d' '40b' '5x' '72h' '7m' 'aa' 'abeille' 'abeitate' 'abelmo'
#  'abelmoschus' 'abies' 'abietata' 'abrial' 'absinthium' 'absolue'
#  'absolute' 'absorbing' 'absorption' 'abyssinica' 'ac' 'acacia' 'acacial'
#  'acai' 'acanthium' 'acanthopanax' 'acephala' 'acer' 'acerola' 'acerosa'
#  'acetal' 'acetamidoethoxyethanol' 'acetate' 'acetic' 'acetoacetate'
#  'acetone' 'acetophenone' 'acetyl' 'acetylarginyltryptophyl' 'acetylated'
#  'acetylcysteine' 'acetylheptapeptide']

# %% [markdown]
# ### Recommending Skincare Products

# %%
import numpy as np
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity

# quick lookup for query product index
name_to_idx = {str(s).strip().lower(): i for i, s in enumerate(df["product_name"].fillna(""))}

def _to_set(x):
    """Normalize None / list / csv-string to a lowercase set."""
    if x is None: return set()
    if isinstance(x, (list, tuple, set, pd.Series, np.ndarray)):
        return {str(t).strip().lower() for t in x if pd.notna(t) and str(t).strip()}
    s = str(x).strip()
    if not s or s.lower() == "nan": return set()
    return {t.strip().lower() for t in s.split(",") if t.strip()}

def content_recommend(
    query_product: str | None = None,
    product_type: str | None = None,
    skin_type: str | None = None,                 # single-select
    skin_concern: list[str] | set[str] | None = None,   # multi-select
    max_price: float | None = None,
    n: int = 10,
    blend_alpha: float = 0.75,   # how much to trust similarity vs. rating/popularity
    min_reviews_for_boost: int = 10
) -> pd.DataFrame:

    # ------------------ compute similarity vector (if query given) ------------------
    sim = None
    if query_product:
        key = str(query_product).strip().lower()
        if key in name_to_idx:
            qidx = name_to_idx[key]
            sim = cosine_similarity(tfidf_matrix[qidx:qidx+1], tfidf_matrix).ravel()
        else:
            # if query not found, we proceed without similarity
            sim = None

    # ------------------ build candidate mask from filters ------------------
    mask = pd.Series(True, index=df.index)

    if product_type:
        req_type = str(product_type).strip().lower()
        mask &= (df["product_type"].fillna("").str.strip().str.lower() == req_type)

    if skin_type:
        req_skin = str(skin_type).strip().lower()
        mask &= df["skin_type"].fillna("").apply(
            lambda s: req_skin in {t.strip().lower() for t in str(s).split(",") if t.strip()}
        )

    req_concerns = _to_set(skin_concern)
    if req_concerns:
        mask &= df["skin_concern"].fillna("").apply(
            lambda s: req_concerns.issubset({t.strip().lower() for t in str(s).split(",") if t.strip()})
        )

    if max_price is not None and "price_usd" in df.columns:
        mask &= pd.to_numeric(df["price_usd"], errors="coerce").fillna(np.inf) <= float(max_price)

    candidates = df[mask].copy()
    if candidates.empty:
        return pd.DataFrame()

    # ------------------ build final score ------------------
    # similarity part (if available)
    if sim is not None:
        candidates = candidates.assign(similarity=sim[candidates.index].astype(float))
    else:
        candidates = candidates.assign(similarity=0.0)

    # popularity part (rating + review_count)
    rating = pd.to_numeric(candidates.get("rating", np.nan), errors="coerce")
    reviews = pd.to_numeric(candidates.get("reviews", 0), errors="coerce").fillna(0)

    # simple popularity score: mean-centered rating * log(1+reviews)
    pop = (rating.fillna(rating.mean())) * np.log1p(np.maximum(reviews, 0))
    # normalize both components to [0,1] to blend sensibly
    def _minmax(x):
        x = x.astype(float)
        mn, mx = np.nanmin(x), np.nanmax(x)
        if not np.isfinite(mn) or not np.isfinite(mx) or mx <= mn:
            return np.zeros_like(x, dtype=float)
        return (x - mn) / (mx - mn)

    sim_norm = _minmax(candidates["similarity"].values)
    pop_norm = _minmax(pop.values)

    # downweight popularity if there are too few reviews
    review_boost = np.clip(reviews / max(min_reviews_for_boost, 1), 0, 1.0)
    pop_norm = pop_norm * review_boost

    final_score = blend_alpha * sim_norm + (1.0 - blend_alpha) * pop_norm
    candidates = candidates.assign(score=final_score)

    # ------------------ sort & format ------------------
    # if we used a query, skip the query item itself
    if query_product and sim is not None:
        key = str(query_product).strip().lower()
        if key in name_to_idx:
            candidates = candidates[candidates.index != name_to_idx[key]]

    out = candidates.sort_values(["score", "similarity", "rating", "reviews"], ascending=False).head(n)

    # nice output columns
    cols = ["product_id","product_name","brand_name","product_type","skin_type","skin_concern",
            "price_usd","rating","review_count","similarity","score"]
    show = [c for c in cols if c in out.columns]
    return out[show].reset_index(drop=True)

# %%
content_recommend(
    query_product="GENIUS Sleeping Collagen Moisturizer",
    product_type="moisturizer",
    skin_type="dry",
    skin_concern=["dehydration"],
    max_price=100,
    n=10
)
# Out:
#   product_id                                       product_name  \
# 0    P453818                     GENIUS Collagen Calming Relief
# 1    P411403  Confidence in a Cream Anti-Aging Hydrating Moi...
# 2    P248407               Ultra Repair Cream Intense Hydration
# 3    P421996      Ultra Facial Moisturizing Cream with Squalane
# 4    P475185          24-7 Moisture Hydrating Day & Night Cream
# 5    P475203     Mini 24-7 Moisture Hydrating Day & Night Cream
# 6    P440312                 Lotus Anti-Aging Night Moisturizer
# 7    P446930                     Cream Skin Toner & Moisturizer
# 8    P436094                   Evercalm Overnight Recovery Balm
# 9    P455369                                Peptide Moisturizer
#
#            brand_name product_type                         skin_type  \
# 0            Algenist  moisturizer  combination,dry,normal,sensitive
# 1        IT Cosmetics  moisturizer            combination,dry,normal
# 2    First Aid Beauty  moisturizer                               dry
# 3  Kiehl's Since 1851  moisturizer            combination,dry,normal
# 4       TULA Skincare  moisturizer            combination,dry,normal
# 5       TULA Skincare  moisturizer            combination,dry,normal
# 6               fresh  moisturizer            combination,dry,normal
# 7             LANEIGE  moisturizer                     dry,sensitive
# 8  REN Clean Skincare  moisturizer            combination,dry,normal
# 9      The INKEY List  moisturizer            combination,dry,normal
#
#                                         skin_concern  price_usd  rating  \
# 0  aging,dehydration,dullness,hyperpigmentation,r...      58.00  4.4640
# 1         aging,dehydration,dullness,redness,texture      20.00  4.6200
# 2     dehydration,dullness,hyperpigmentation,redness      38.00  4.5200
# 3  acne,dehydration,dullness,oil-control,pores,te...      78.00  4.4469
# 4  aging,dehydration,dullness,hyperpigmentation,t...      54.00  4.1884
# 5  aging,dehydration,dullness,hyperpigmentation,t...      26.00  4.1884
# 6                                  aging,dehydration      56.00  4.4843
# 7                                        dehydration      33.00  4.4481
# 8               dehydration,dullness,redness,texture      55.00  4.4864
# 9                                  aging,dehydration      15.99  3.7913
#
#    similarity     score
# 0    0.372106  0.400237
# 1    0.189315  0.349495
# 2    0.134077  0.333196
# 3    0.166320  0.323746
# 4    0.236256  0.317278
# 5    0.236111  0.317166
# 6    0.164671  0.313202
# 7    0.151063  0.303730
# 8    0.187106  0.302916
# 9    0.213639  0.300933

# %% [markdown]
# ### Evaluation metrics

# %%
import numpy as np
import pandas as pd
from math import sqrt
from sklearn.metrics import mean_squared_error

# df = pd.read_csv("data/CleanedDataSet/products_preprocessed.csv")
# reviews = pd.read_csv("data/CleanedDataSet/filtered_skincare_reviews.csv")

def evaluate_all_metrics(
    reviews: pd.DataFrame,
    *,
    # RMSE/MAE params
    top_n: int = 5,
    sample_size: int = 500,
    liked_threshold: float = 3.5,
    # Precision/Recall/F1 params
    K: int = 10,
    min_rating: float = 4.0,
    min_reviews: int = 20,
    max_items: int | None = None,
    # relevance options
    require_concern_overlap: bool = True,
    verbose: bool = True,
):

    # -----------------------------
    # MSE / RMSE / MAE
    # -----------------------------
    # Validate reviews columns
    for col in ["author_id", "product_id", "rating"]:
        if col not in reviews.columns:
            raise ValueError(f"Missing column in reviews: {col}")

    # Ensure df has product_id (or synthesize one)
    if "product_id" not in df.columns:
        df["product_id"] = np.arange(len(df))

    rated = reviews.copy()
    rated["rating"] = pd.to_numeric(rated["rating"], errors="coerce")
    rated = rated.dropna(subset=["author_id", "product_id", "rating"])

    valid_ids = set(df["product_id"])
    rated = rated[rated["product_id"].isin(valid_ids)]

    # users with >=2 liked items
    likes = (rated[rated["rating"] >= liked_threshold]
             .groupby("author_id")["product_id"].apply(list).to_dict())
    eligible = [(u, lst) for u, lst in likes.items() if len(set(lst)) >= 2]

    # user sampling
    if sample_size and sample_size < len(eligible):
        idx = np.random.choice(len(eligible), size=sample_size, replace=False)
        eligible = [eligible[i] for i in idx]

    y_true, y_pred, abs_errs, skipped = [], [], [], 0

    for user, liked in eligible:
        liked = [pid for pid in liked if pid in valid_ids]
        if len(liked) < 2:
            skipped += 1
            continue

        q = np.random.choice(liked)
        qrow = df.loc[df["product_id"] == q]
        if qrow.empty:
            skipped += 1
            continue
        qrow = qrow.iloc[0]

        recs = contentbased_recommender(
            product_type=qrow.get("product_type"),
            skin_type=qrow.get("skin_type"),
            skin_concern=qrow.get("skin_concern").split(",") if isinstance(qrow.get("skin_concern"), str) else None,
            concern_match="all",
            max_price=qrow.get("price_usd"),
            n=top_n
        )
        if recs is None or len(recs) == 0:
            skipped += 1
            continue

        r_ratings = pd.to_numeric(recs.get("rating"), errors="coerce").fillna(0).to_numpy()
        r_sims    = pd.to_numeric(recs.get("similarity"), errors="coerce").fillna(0).to_numpy()
        if r_ratings.size == 0 or r_sims.sum() == 0:
            skipped += 1
            continue

        pred_rating = float(np.average(r_ratings, weights=np.clip(r_sims, 1e-6, None)))

        # ground truth (this user's rating for held-out product)
        held = rated.loc[(rated["author_id"] == user) & (rated["product_id"] == q), "rating"]
        if held.empty:
            skipped += 1
            continue

        true_rating = float(held.iloc[0])
        y_true.append(true_rating)
        y_pred.append(pred_rating)
        abs_errs.append(abs(true_rating - pred_rating))

    mse_val = mean_squared_error(y_true, y_pred) if y_true else None
    rmse_val = sqrt(mse_val) if mse_val is not None else None
    mae_val = float(np.mean(abs_errs)) if abs_errs else None

    # -----------------------------
    # Precision / Recall / F1 (proxy)
    # -----------------------------
    df_local = df.copy()
    # handle rating + review count column names
    rating_col = "rating" if "rating" in df_local.columns else None
    reviews_col = "review_count" if "review_count" in df_local.columns else ("reviews" if "reviews" in df_local.columns else None)
    if rating_col is None:
        raise ValueError("`df` needs a product-level 'rating' column for proxy relevance.")
    if reviews_col is None:
        # create one if missing
        df_local["review_count"] = 0
        reviews_col = "review_count"

    df_local[rating_col]  = pd.to_numeric(df_local[rating_col], errors="coerce")
    df_local[reviews_col] = pd.to_numeric(df_local[reviews_col], errors="coerce").fillna(0)

    items = df_local.index.tolist()
    if max_items:
        items = items[:max_items]

    precisions, recalls, f1s, n_eval_rank = [], [], [], 0

    for i in items:
        q = df_local.iloc[i]
        q_name = q.get("product_name", None)
        if not isinstance(q_name, str) or not q_name.strip():
            continue

        q_type = str(q.get("product_type", "")).strip().lower()
        q_skin = q.get("skin_type", None)
        q_concerns = {t.strip().lower() for t in str(q.get("skin_concern", "")).split(",") if t.strip()}

        rel = df_local[
            (df_local.index != i) &
            (df_local["product_type"].fillna("").str.strip().str.lower() == q_type) &
            (df_local[rating_col] >= min_rating) &
            (df_local[reviews_col] >= min_reviews)
        ].copy()
        if require_concern_overlap and q_concerns:
            rel = rel[rel["skin_concern"].fillna("").apply(lambda s: len(q_concerns & {t.strip().lower() for t in str(s).split(",") if t.strip()}) > 0)]

        if rel.empty:
            continue
        relevant_names = set(rel["product_name"].tolist())

        # Use query+filters recommender for ranking
        recs = content_recommend(
            query_product=q_name,
            product_type=q_type or None,
            skin_type=q_skin or None,
            skin_concern=list(q_concerns) if q_concerns else None,
            n=K
        )
        if recs is None or recs.empty:
            continue

        rec_names = set(recs["product_name"].tolist())
        hits = len(rec_names & relevant_names)

        precision = hits / float(K)
        recall = hits / float(len(relevant_names))
        f1 = 2 * precision * recall / (precision + recall + 1e-9)

        precisions.append(precision)
        recalls.append(recall)
        f1s.append(f1)
        n_eval_rank += 1


    if verbose:
        print("\n=== Content-based Evaluation ===")
        if y_true:
            print(f"Users/items evaluated: {len(y_true)}  |  skipped: {skipped}")
            print(f"MSE:  {mse_val:.4f}")
            print(f"RMSE: {rmse_val:.4f}")
            print(f"MAE:  {mae_val:.4f}")
        else:
            print("No valid predictions made (check reviews coverage).")

        if n_eval_rank > 0:
            print(f"Queries evaluated: {n_eval_rank}")
            print(f"Precision@{K}: {np.mean(precisions):.4f}")
            print(f"Recall@{K}:    {np.mean(recalls):.4f}")
            print(f"F1@{K}:        {np.mean(f1s):.4f}")
        else:
            print("No valid queries for proxy evaluation (check thresholds).")

    return {
        "rating_prediction": {
            "n_evaluated": len(y_true),
            "skipped": skipped,
            "mse": mse_val,
            "rmse": rmse_val,
            "mae": mae_val,
        },
        "ranking_proxy": {
            "n_evaluated": n_eval_rank,
            f"P@{K}": float(np.mean(precisions)) if n_eval_rank>0 else None,
            f"R@{K}": float(np.mean(recalls))    if n_eval_rank>0 else None,
            f"F1@{K}": float(np.mean(f1s))      if n_eval_rank>0 else None,
        }
    }

# %%
results = evaluate_all_metrics(
    reviews,
    top_n=5, sample_size=200, liked_threshold=3.5,   
    K=10, min_rating=4.0, min_reviews=20,             
    require_concern_overlap=True, max_items=None      
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 results = evaluate_all_metrics(
#       2     reviews,
#       3     top_n=5, sample_size=200, liked_threshold=3.5,
#       4     K=10, min_rating=4.0, min_reviews=20,
#       5     require_concern_overlap=True, max_items=None
#       6 )
#
# Cell In[47], line 70, in evaluate_all_metrics(reviews, top_n, sample_size, liked_threshold, K, min_rating, min_reviews, max_items, require_concern_overlap, verbose)
#      67     continue
#      68 qrow = qrow.iloc[0]
# ---> 70 recs = content_recommend(
#      71     product_type=qrow.get("product_type"),
#      72     skin_type=qrow.get("skin_type"),
#      73     skin_concern=qrow.get("skin_concern").split(",") if isinstance(qrow.get("skin_concern"), str) else None,
#      74     concern_match="all",
#      75     max_price=qrow.get("price_usd"),
#      76     n=top_n
#      77 )
#      78 if recs is None or len(recs) == 0:
#      79     skipped += 1
#
# TypeError: content_recommend() got an unexpected keyword argument 'concern_match'

# %% [markdown]
# ## Collaborative Filtering - Chang Kar Yan

# %% [markdown]
# ### SVD

# %%
import pandas as pd
import numpy as np
from surprise import SVD, Dataset, Reader, accuracy
from surprise.model_selection import GridSearchCV, train_test_split
from collections import defaultdict
from tqdm import tqdm
import pickle

# Prepare data
df = df_review[['author_id', 'product_id', 'rating', 'product_name', 'brand_name', 'skin_type', 'price_usd', 'secondary_category', 'tertiary_category']].copy()

# Validate ratings (1–5)
df = df[df['rating'].between(1, 5)]
print(f"Shape after grouping and rating validation: {df.shape}")
print(f"Unique users: {df['author_id'].nunique()}, Unique products: {df['product_id'].nunique()}")

# Filter sparse entries
min_user_reviews = 5
min_product_reviews = 10
user_counts = df['author_id'].value_counts()
product_counts = df['product_id'].value_counts()
valid_users = user_counts[user_counts >= min_user_reviews].index
valid_products = product_counts[product_counts >= min_product_reviews].index
df = df[df['author_id'].isin(valid_users) & df['product_id'].isin(valid_products)]
print(f"Filtered shape (users≥{min_user_reviews}, products≥{min_product_reviews}): {df.shape}")
print(f"Sparsity: {1 - len(df) / (df['author_id'].nunique() * df['product_id'].nunique()):.4f}")

# Check for sufficient data
if df.empty:
    raise ValueError("Filtered dataset is empty. Adjust min_user_reviews or min_product_reviews.")

# Check for NaN values
if df[['author_id', 'product_id', 'rating']].isna().any().any():
    print("Warning: NaN values found in critical columns. Dropping NaN rows.")
    df = df.dropna(subset=['author_id', 'product_id', 'rating'])

# Save the training dataframe as CSV
training_csv_filename = "data/CleanedDataSet/collaborative_training_data.csv"
df.to_csv(training_csv_filename, index=False)
print(f"Training data saved as: {training_csv_filename}")
print(f"Training CSV contains:")
print(f"- {len(df)} records")
print(f"- {df['author_id'].nunique()} unique users")
print(f"- {df['product_id'].nunique()} unique products")
print(f"- Columns: {list(df.columns)}")

# Verify the saved file
verify_df = pd.read_csv(training_csv_filename)
print(f"\nVerification - loaded CSV has {len(verify_df)} rows and {len(verify_df.columns)} columns")

# Load into Surprise
reader = Reader(rating_scale=(1, 5))
data = Dataset.load_from_df(df[['author_id', 'product_id', 'rating']], reader)
trainset, testset = train_test_split(data, test_size=0.2, random_state=42)

# GridSearchCV for SVD with progress bar
param_grid = {
    'n_factors': [10, 20, 50],
    'n_epochs': [20, 30],
    'lr_all': [0.005, 0.01],
    'reg_all': [0.1, 0.2]
}
gs_svd = GridSearchCV(SVD, param_grid, measures=['rmse', 'mae'], cv=3, n_jobs=1)
print("Running GridSearchCV for SVD...")
gs_svd.fit(data)
print("\nBest SVD Parameters:")
print(f"RMSE: {gs_svd.best_score['rmse']:.3f}, Params: {gs_svd.best_params['rmse']}")
print(f"MAE: {gs_svd.best_score['mae']:.3f}, Params: {gs_svd.best_params['mae']}")

# Train SVD with best parameters
best_svd = SVD(
    n_factors=gs_svd.best_params['rmse']['n_factors'],
    n_epochs=gs_svd.best_params['rmse']['n_epochs'],
    lr_all=gs_svd.best_params['rmse']['lr_all'],
    reg_all=gs_svd.best_params['rmse']['reg_all'],
    random_state=42
)
best_svd.fit(trainset)

# Save the trained SVD model and trainset to .pkl files
with open('models/svd_model.pkl', 'wb') as f:
    pickle.dump(best_svd, f)
with open('models/trainset.pkl', 'wb') as f:
    pickle.dump(trainset, f)
print("Model and trainset saved to 'models/svd_model.pkl' and 'models/trainset.pkl'.")

# Calculate evaluation metrics
svd_preds = best_svd.test(testset)
svd_rmse = accuracy.rmse(svd_preds, verbose=True)
svd_mae = accuracy.mae(svd_preds, verbose=True)
svd_mse = np.mean([(pred.est - pred.r_ui) ** 2 for pred in svd_preds])
svd_accuracy = np.mean([1 if round(pred.est) == round(pred.r_ui) else 0 for pred in svd_preds])

# Precision@K, Recall@K, and F1@K with progress bar
def precision_recall_f1_at_k(predictions, k=5, threshold=4.0):
    user_est_true = defaultdict(list)
    for pred in tqdm(predictions, desc="Building user predictions"):
        user_est_true[pred.uid].append((pred.est, pred.r_ui))
    
    precisions, recalls = [], []
    for uid, ratings in tqdm(user_est_true.items(), desc="Calculating metrics"):
        ratings.sort(key=lambda x: x[0], reverse=True)
        n_rel = sum((true_r >= threshold) for _, true_r in ratings)
        n_rec_k = sum((est >= threshold) for est, _ in ratings[:k])
        n_rel_and_rec_k = sum((true_r >= threshold) for _, true_r in ratings[:k])
        precision = n_rel_and_rec_k / n_rec_k if n_rec_k != 0 else 0
        recall = n_rel_and_rec_k / n_rel if n_rel != 0 else 0
        precisions.append(precision)
        recalls.append(recall)
        if n_rec_k == 0 or n_rel == 0:
            print(f"User {uid}: Zero precision/recall (n_rec_k={n_rec_k}, n_rel={n_rel})")
    
    avg_precision = sum(precisions) / len(precisions)
    avg_recall = sum(recalls) / len(recalls)
    f1 = 2 * (avg_precision * avg_recall) / (avg_precision + avg_recall) if (avg_precision + avg_recall) != 0 else 0
    return avg_precision, avg_recall, f1
# Out:
# Shape after grouping and rating validation: (798983, 9)
# Unique users: 455845, Unique products: 1765
# Filtered shape (users≥5, products≥10): (187770, 9)
# Sparsity: 0.9942
# Training data saved as: data/CleanedDataSet/collaborative_training_data.csv
# Training CSV contains:
# - 187770 records
# - 20855 unique users
# - 1544 unique products
# - Columns: ['author_id', 'product_id', 'rating', 'product_name', 'brand_name', 'skin_type', 'price_usd', 'secondary_category', 'tertiary_category']
#
# Verification - loaded CSV has 187770 rows and 9 columns
# Running GridSearchCV for SVD...
#
# Best SVD Parameters:
# RMSE: 0.860, Params: {'n_factors': 50, 'n_epochs': 30, 'lr_all': 0.01, 'reg_all': 0.1}
# MAE: 0.581, Params: {'n_factors': 50, 'n_epochs': 30, 'lr_all': 0.01, 'reg_all': 0.1}
# Model and trainset saved to 'models/svd_model.pkl' and 'models/trainset.pkl'.
# RMSE: 0.8517
# MAE:  0.5752

# %%
# Evaluate Precision@K, Recall@K, and F1@K
svd_prec, svd_rec, svd_f1 = precision_recall_f1_at_k(svd_preds, k=5, threshold=4.0)
# Out:
# Building user predictions: 100%|██████████| 37554/37554 [00:00<00:00, 72211.12it/s]
# Calculating metrics:  83%|████████▎ | 13534/16287 [00:00<00:00, 68201.01it/s]
# User 6064061494: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 8329057844: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 6521784323: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1387153597: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 8449561965: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 2824877486: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 2249756960: Zero precision/recall (n_rec_k=0, n_rel=3)
# User 22356537078: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 12342926958: Zero precision/recall (n_rec_k=0, n_rel=3)
# User 8297640948: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 2613359305: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 5255411797: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 6260043687: Zero precision/recall (n_rec_k=0, n_rel=3)
# User 6553981255: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1902395271: Zero precision/recall (n_rec_k=0, n_rel=3)
# User 5681729741: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 23427456326: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 1330750144: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 2249180625: Zero precision/recall (n_rec_k=0, n_rel=5)
# User 7284212684: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 12322516527: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 2410322562: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 2176423867: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1552876300: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 5138741618: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1392325989: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 10412397880: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 5133034734: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 2440374032: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 1405351453: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 12796486348: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 6978719176: Zero precision/recall (n_rec_k=3, n_rel=0)
# User 2857873996: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 2776710623: Zero precision/recall (n_rec_k=0, n_rel=4)
# User 5552471018: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 5889041135: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 6644585416: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 9012861878: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 1184105746: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 7248198696: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 24484214663: Zero precision/recall (n_rec_k=0, n_rel=4)
# User 876771001: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 12472650439: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 2283104964: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 26922813892: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 6341291441: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 22099662861: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 1910820517: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1179445753: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 12132612440: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 1313086934: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 7910996322: Zero precision/recall (n_rec_k=2, n_rel=0)
# User 1936758628: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 5063075930: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 7123237666: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 9075527849: Zero precision/recall (n_rec_k=0, n_rel=5)
# User 6231597929: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 25844185304: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 13044976138: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1171528521: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 11069839843: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 7570377887: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 9392163568: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 5120351325: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 2810836372: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 5838653930: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 6070053218: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1377748799: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 30393792331: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 2187923579: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 989206537: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 6946141802: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 20231663865: Zero precision/recall (n_rec_k=2, n_rel=0)
# User 10788962834: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 2622932346: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 9026665187: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 5974005586: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1051238386: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 10584526523: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 5625193712: Zero precision/recall (n_rec_k=0, n_rel=3)
# User 6313799524: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1710591149: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 6891577721: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 2329422551: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 5161142406: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 29442955130: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1348221401: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1306364616: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 24610906162: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 23403759394: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 9161311330: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 5799687861: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 5129097200: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1113044942: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 7116473157: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 7700337132: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 6079271522: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 12163564218: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 5376465978: Zero precision/recall (n_rec_k=0, n_rel=5)
# User 37423201643: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 2200957288: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 25140074472: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1996582841: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 21405562299: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1930072375: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1771460598: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 2155610959: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 5984044602: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 11442033172: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 1186029140: Zero precision/recall (n_rec_k=2, n_rel=0)
# User 1777494219: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 9181810277: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 6118535519: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1567396046: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 8432275866: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 5154244197: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 2724653436: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 7872374446: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 5767026669: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 2718765214: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 8619603739: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 28336066029: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 9154757545: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 5721109042: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 22113047235: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 24711945604: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 2775041877: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 2796730954: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 22986469823: Zero precision/recall (n_rec_k=0, n_rel=3)
# User 5641065138: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 2542410142: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 956326259: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1000235057: Zero precision/recall (n_rec_k=0, n_rel=3)
# User 6452718628: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 5514069760: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 2220494703: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 1321157226: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 1119846943: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 1322507145: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 6112212868: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1364720723: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1787395511: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1616300058: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 10688219775: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1824451617: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 30477385322: Zero precision/recall (n_rec_k=0, n_rel=8)
# User 10979743167: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 21360571422: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 20178901362: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 7877324362: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1160374636: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 1812803159: Zero precision/recall (n_rec_k=0, n_rel=3)
# User 2604303835: Zero precision/recall (n_rec_k=0, n_rel=3)
# User 1321153820: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 6100693907: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 8629663433: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 5110575395: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 907820404: Zero precision/recall (n_rec_k=2, n_rel=0)
# User 2180691437: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 9981215864: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 6212970852: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 1297916973: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 23107906466: Zero precision/recall (n_rec_k=0, n_rel=3)
# User 7605225095: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 1665197928: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1330750144: Zero precision/recall (n_rec_k=0, n_rel=5)
# User 7386946069: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 6481489712: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 32372455385: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 8987275206: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1895658020: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 7814120517: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 2691005552: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 7494326272: Zero precision/recall (n_rec_k=0, n_rel=3)
# User 11107040249: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 23041128999: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 2150221742: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1809763160: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 5668237756: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 2486834357: Zero precision/recall (n_rec_k=0, n_rel=3)
# User 6238945433: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 5195315915: Zero precision/recall (n_rec_k=0, n_rel=3)
# User 6023626729: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1348674324: Zero precision/recall (n_rec_k=2, n_rel=0)
# User 35243011496: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 22606312978: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 2273912671: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 2279101169: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 6581846678: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 5448492702: Zero precision/recall (n_rec_k=0, n_rel=4)
# User 12978445724: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1722725925: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 31828700811: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 6330442297: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 2274105192: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1716384087: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 9168759089: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 22760739468: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 8439343207: Zero precision/recall (n_rec_k=0, n_rel=3)
# User 10298106678: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1274186086: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 25654631850: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 2277970397: Zero precision/recall (n_rec_k=0, n_rel=5)
# User 6846147159: Zero precision/recall (n_rec_k=2, n_rel=0)
# User 2196916921: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 10854131680: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 2838234720: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 9413668208: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 2147510807: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 2803385228: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 10742892009: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 1075448934: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1341670663: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 13086644666: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1174217857: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 8144258416: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 1812112819: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 1518882390: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 11283765727: Zero precision/recall (n_rec_k=2, n_rel=0)
# User 6667310234: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1018251431: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1653505361: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 22691357762: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 6645716272: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 6663364326: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1337563286: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 8830011597: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 2720310272: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 10200097454: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 8968676737: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 7502652587: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 8299833317: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 6150454367: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 1313590540: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 5860315483: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 12788915845: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 8042900596: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 6338198485: Zero precision/recall (n_rec_k=0, n_rel=4)
# User 2272380606: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 8362273676: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 1428165243: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 1995764508: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 5145756053: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 7129997613: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 22834773898: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 2339266470: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 2664482674: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1376032490: Zero precision/recall (n_rec_k=2, n_rel=0)
# User 28837725993: Zero precision/recall (n_rec_k=2, n_rel=0)
# User 1840206213: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 974009664: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 8690690194: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 9094626762: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 25344877156: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 21156228197: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 2110743530: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 32574548251: Zero precision/recall (n_rec_k=0, n_rel=4)
# User 7773242993: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 2523261963: Zero precision/recall (n_rec_k=0, n_rel=5)
# User 6140441201: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 2182414128: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 1314615528: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 23003620626: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 13025614098: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 1410642769: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 7751129653: Zero precision/recall (n_rec_k=0, n_rel=3)
# User 986455408: Zero precision/recall (n_rec_k=0, n_rel=3)
# User 8443361202: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 6588237708: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 1431460782: Zero precision/recall (n_rec_k=0, n_rel=4)
# User 1383741311: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1149526579: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 965902195: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 28855848657: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1345088629: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 5698627875: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 10859264145: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 22109244286: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 12327533870: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 11007471034: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 6867427676: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1867051566: Zero precision/recall (n_rec_k=2, n_rel=0)
# User 10848560086: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 5553063976: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 39684120535: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 6021223815: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 2033242595: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1221945092: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1301375885: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 25945605885: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 23134201327: Zero precision/recall (n_rec_k=0, n_rel=5)
# User 1327614666: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1512540039: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1315809538: Zero precision/recall (n_rec_k=3, n_rel=0)
# User 27878509487: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 2165269829: Zero precision/recall (n_rec_k=2, n_rel=0)
# User 9262629686: Zero precision/recall (n_rec_k=0, n_rel=3)
# User 1964997515: Zero precision/recall (n_rec_k=0, n_rel=3)
# User 8676327110: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1828731029: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 21163387302: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 5624401163: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 11560753411: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 27368098828: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 1398085790: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1933264055: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 6729267615: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 5801174718: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 24712028933: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 1067240100: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 29664585805: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1312693618: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 9963280276: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 5775700435: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 12162181107: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 12333063921: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 7930074585: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 5784953349: Zero precision/recall (n_rec_k=0, n_rel=5)
# User 1527145519: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 5057796906: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 5302315777: Zero precision/recall (n_rec_k=0, n_rel=4)
# User 1436108943: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 2112707935: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 22728211603: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 8275628975: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 1747971900: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 9859509728: Zero precision/recall (n_rec_k=2, n_rel=0)
# User 5478223660: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 25196349083: Zero precision/recall (n_rec_k=0, n_rel=5)
# User 5409561617: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 2139366383: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 5422666543: Zero precision/recall (n_rec_k=0, n_rel=3)
# User 5133071741: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 1128429967: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 8445618119: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 6692567813: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 1834156807: Zero precision/recall (n_rec_k=2, n_rel=0)
# User 27790988019: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 26895303111: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1414382418: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 7618862311: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 24294093872: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 2074011542: Zero precision/recall (n_rec_k=0, n_rel=6)
# User 5803255942: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 2336033047: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 8594314942: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 22171595959: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 5544858613: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 2021239927: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 20222837575: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 9215544077: Zero precision/recall (n_rec_k=2, n_rel=0)
# User 1783150064: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 5899011003: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 2826108304: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 6064395603: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 2195743595: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 32052998633: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 6805178570: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1443642557: Zero precision/recall (n_rec_k=0, n_rel=3)
# User 1491844059: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 9214430200: Zero precision/recall (n_rec_k=3, n_rel=0)
# User 8714225928: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 1381179223: Zero precision/recall (n_rec_k=2, n_rel=0)
# User 31704583556: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 1365792782: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1959185816: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1117502448: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 6186173180: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 23416066765: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 6748571594: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 12888772231: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 21133044055: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 28070885315: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 7025310719: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 5695294622: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 11876340705: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 5067122322: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 8730698646: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 1788081732: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 11225147983: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 22998720793: Zero precision/recall (n_rec_k=0, n_rel=3)
# User 9727245538: Zero precision/recall (n_rec_k=2, n_rel=0)
# User 9984441443: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1593738894: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 22401041848: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 28870853254: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 2481381586: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 6554400169: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 2312933823: Zero precision/recall (n_rec_k=2, n_rel=0)
# User 1025754398: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 5957653766: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 12698797425: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 2724420747: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 1317185638: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 7399615203: Zero precision/recall (n_rec_k=0, n_rel=6)
# User 7509424015: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 32281467476: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 30533064578: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 2617700011: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 12061118297: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 22969483279: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1228733025: Zero precision/recall (n_rec_k=0, n_rel=3)
# User 24388667924: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 9342610561: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 11034526880: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 5471571245: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 7190066206: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 5462260193: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1937748738: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 1784480727: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 7352533339: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 11818216307: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 979810128: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 26364844071: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1870323043: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 21384966981: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 5475007004: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 11834932983: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 2839938054: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 21960784266: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 2808060267: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 7202412418: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 2292492976: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 5667889608: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 1550296159: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 5382742260: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1322762051: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 955344206: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 5570985948: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1338487002: Zero precision/recall (n_rec_k=0, n_rel=3)
# User 2593843151: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1432001315: Zero precision/recall (n_rec_k=0, n_rel=3)
# User 1833452906: Zero precision/recall (n_rec_k=0, n_rel=3)
# User 1877954109: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 28364981361: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 12886973125: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1404745063: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 10128500822: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 2006170533: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 10885915468: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 1417492020: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 7659604178: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 6773237448: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 21788407849: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 6914155649: Zero precision/recall (n_rec_k=2, n_rel=0)
# User 9084645222: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 2130136606: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 6469415655: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 2019442875: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 25602669269: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 6016281489: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 12437963023: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 2029522112: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 28131488917: Zero precision/recall (n_rec_k=0, n_rel=4)
# User 1307884151: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1767230529: Zero precision/recall (n_rec_k=0, n_rel=4)
# User 12268338765: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 1248738688: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 22569759963: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 5450596970: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 6536873268: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 5397066922: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 2793121923: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 2387895102: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 8663259569: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 25871224658: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 8875945647: Zero precision/recall (n_rec_k=0, n_rel=3)
# User 11111231602: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 2073034914: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 9413701297: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 5337720788: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 8889275463: Zero precision/recall (n_rec_k=0, n_rel=4)
# User 22077513605: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 6848102740: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 2559975776: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 5322307553: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 7218063279: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 22405327899: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 5856204820: Zero precision/recall (n_rec_k=0, n_rel=7)
# User 1064543595: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 5377077345: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 5813211406: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1463083160: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 5043304561: Zero precision/recall (n_rec_k=0, n_rel=3)
# User 927424176: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 8205168237: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1384391078: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 2118515570: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 21696149927: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 26050300155: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 7977695307: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1229783611: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 1621592407: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 7575942564: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1553331512: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1416051610: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 2028396948: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 6126157016: Zero precision/recall (n_rec_k=0, n_rel=3)
# User 782670213: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1757045265: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 2018172376: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 2138255080: Zero precision/recall (n_rec_k=0, n_rel=6)
# User 2466211527: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 2748254265: Zero precision/recall (n_rec_k=2, n_rel=0)
# User 8898610903: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1340125595: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 5248510026: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1082334148: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 2238155550: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1600220303: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 1336311186: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1307532288: Zero precision/recall (n_rec_k=2, n_rel=0)
# User 11610060803: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 22038701417: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 6073183667: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 11058943345: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1567396046: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1467083822: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 9556547633: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 11417021154: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 6559471539: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 2855186881: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1845182527: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 5187083011: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 5230020288: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 5969266197: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 2451073093: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 2768130400: Zero precision/recall (n_rec_k=2, n_rel=0)
# User 8399183915: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 1747971900: Zero precision/recall (n_rec_k=0, n_rel=6)
# User 2617697118: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1633398072: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1713612484: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 2378386998: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 1111551719: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 6220353485: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1398091732: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 7378865220: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 2211181604: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 2116782111: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 22093970208: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 35565734141: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 11338347811: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 1322196707: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 5434878680: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 12956000966: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 2775047039: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 9205103528: Zero precision/recall (n_rec_k=0, n_rel=7)
# User 2545613012: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 5160314030: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 5327824037: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 2134661460: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 7219593634: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 5219097527: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 1644390427: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 6375959586: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 7150135816: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1594303154: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 7856055783: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 6517824574: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 6957586578: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 22743494793: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1313308937: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 11068938255: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 5726390070: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 6387370252: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 1770130466: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 10005368592: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 11075633990: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 8620221691: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 6381131595: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 23582012155: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 5998457750: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1499051108: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1212524782: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 12008667571: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 9611277721: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1599616062: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 12666463375: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 5591850928: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 7073915302: Zero precision/recall (n_rec_k=0, n_rel=3)
# User 1945571755: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 5358298469: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 5516894623: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 22850931514: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 24261870502: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1558402873: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 31826917235: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 27615952471: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 6830612821: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 1095742612: Zero precision/recall (n_rec_k=0, n_rel=5)
# User 5439327645: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 107568716: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1477662830: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 21441813998: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 2299822163: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 2123092132: Zero precision/recall (n_rec_k=2, n_rel=0)
# User 8462343680: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 24666609103: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 30216803960: Zero precision/recall (n_rec_k=0, n_rel=8)
# User 2715445662: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 8691341332: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 2037160832: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 2549667253: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 2492724338: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1193691965: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 5803389147: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 31359408635: Zero precision/recall (n_rec_k=2, n_rel=0)
# User 5338050083: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1532152118: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 22934451719: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 7210891403: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1485599114: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 26824759452: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 1492634822: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 6057721901: Zero precision/recall (n_rec_k=0, n_rel=3)
# User 1527154349: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 2160084337: Zero precision/recall (n_rec_k=2, n_rel=0)
# User 21936601848: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 9231869520: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1666846910: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 5051683809: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 8444793501: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 30105776843: Zero precision/recall (n_rec_k=0, n_rel=3)
# User 12873525230: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 11438671677: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 21391423705: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 5353658244: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1501988175: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1845711259: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 5373354641: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 22404728218: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 21360267542: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 1473585203: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1737922340: Zero precision/recall (n_rec_k=0, n_rel=6)
# User 2261180551: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 5738565556: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 913476780: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 30233925404: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 5802677362: Zero precision/recall (n_rec_k=0, n_rel=4)
# User 8774602224: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 20867850340: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 5543589517: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 1911102231: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 22632326963: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1604563671: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 9210818854: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 2670458340: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 1994061344: Zero precision/recall (n_rec_k=2, n_rel=0)
# User 5581325343: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 7656750306: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1104599277: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 29807909403: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 10218496336: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 2808255626: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 7574029114: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1354194978: Zero precision/recall (n_rec_k=0, n_rel=3)
# User 1114373345: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 1312839211: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1297545906: Zero precision/recall (n_rec_k=0, n_rel=3)
# User 2708897925: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 7548746802: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 2475953306: Zero precision/recall (n_rec_k=2, n_rel=0)
# User 8774652735: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 21950544973: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 2230534461: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 6009854722: Zero precision/recall (n_rec_k=0, n_rel=3)
# User 2203403050: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 2329293283: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 23048849960: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1171567209: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 1707494267: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 7651579576: Zero precision/recall (n_rec_k=0, n_rel=3)
# User 910782679: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 7257001210: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 27996782026: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 2486823994: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 1780811141: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 9016489580: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 9033785625: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 12200559171: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 8708456521: Zero precision/recall (n_rec_k=0, n_rel=4)
# User 2074714813: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 13086884515: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 2677448975: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 29429797221: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1448847240: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 2221731249: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 954726902: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 9476121067: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 5446033344: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 5906301363: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1976785611: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 27916047621: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1995753523: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 11488850619: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1665212146: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 8629663433: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1123843256: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 2528810992: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 7801400354: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 23909903004: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 5641703174: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1329206643: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 5284979564: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 2532133394: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1313693902: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 23403759394: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1527654838: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 6540764046: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 9969910538: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1327606217: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 2439490942: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 7988181041: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 11922996604: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 8476486187: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 5082932105: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 990164384: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 6654075222: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 2580191662: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 7354080863: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 2154853752: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 7679794981: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 12523348784: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 2490723220: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 5450514868: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1425225368: Zero precision/recall (n_rec_k=3, n_rel=0)
# User 7182570726: Zero precision/recall (n_rec_k=2, n_rel=0)
# User 11801200898: Zero precision/recall (n_rec_k=2, n_rel=0)
# User 5229784484: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 5577333808: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 8033003400: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 27609691854: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 6407896211: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 22189696729: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 5514821722: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1577910168: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 5714819625: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 7191222508: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 8838374354: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 12623503451: Zero precision/recall (n_rec_k=0, n_rel=4)
# User 6142383918: Zero precision/recall (n_rec_k=0, n_rel=3)
# User 11299096469: Zero precision/recall (n_rec_k=0, n_rel=3)
# User 5655554425: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 21803455832: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 5840707250: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 7305161013: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 12041524161: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 1328797117: Zero precision/recall (n_rec_k=0, n_rel=7)
# User 11479387693: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 2515857948: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 10755809236: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 6845267926: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1639036821: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 6624225862: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 11237402987: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 31635788543: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1324804477: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 2597686382: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 7265378560: Zero precision/recall (n_rec_k=0, n_rel=4)
# User 8327892887: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 5758305258: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 23181847647: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 2049919849: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 2595043814: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 2490192578: Zero precision/recall (n_rec_k=2, n_rel=0)
# User 21981694304: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 11225139285: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 5058739724: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 1065883610: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 6629681194: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 5273398886: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 998951943: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 12853169830: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 21714709642: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 6002456477: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 10544388370: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1796832389: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 23400488729: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 12550135717: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 6822265904: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1631571177: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 6904003101: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 5580256101: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 5927224975: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 6344113983: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 2445681007: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1045420588: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 11034532816: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 10696524140: Zero precision/recall (n_rec_k=0, n_rel=3)
# User 10364136479: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 5275678549: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 2397204424: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 6128457892: Zero precision/recall (n_rec_k=0, n_rel=1)
# ...
# User 2310922419: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 5606989755: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 11184219311: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 5333451040: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 922087687: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 5743123923: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 996863828: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1530293263: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 12585258036: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 30914205803: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 2361763220: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 11274081541: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1877319283: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1785823063: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 25331740902: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 2430611956: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 5555707793: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 904740205: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1023515356: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 23587674109: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 8873851320: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 560068450: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 27467483163: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 5776299759: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 8205090437: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1435098972: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1888931724: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 6219704326: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 29502636319: Zero precision/recall (n_rec_k=0, n_rel=1)
# Calculating metrics: 100%|██████████| 16287/16287 [00:00<00:00, 70354.24it/s]
# User 1919579971: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 1123510631: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 6019743528: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 1345372453: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1552435311: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 2046134664: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 21623426190: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 2514943993: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 2854914091: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 6254546452: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 2094719470: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1060723157: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 6676717329: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 5066502139: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 1036122836: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1249448991: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1533594461: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1758343913: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 5893987402: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 5470880820: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 22104804475: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 22701976506: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 6522039071: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 6965517067: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1176898335: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 8869465673: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 7714906159: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 968244717: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 6959106567: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 23245537456: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 2180463903: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1430199637: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 23550954273: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 21065032544: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 7541491224: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 5130854691: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 5964963298: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 8866165191: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 5397428426: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 6154130490: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 6356324280: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 8270889102: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 1918898564: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 5726881154: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 10601744097: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 6139073798: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 22343439326: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 6240024098: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 9600079372: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 7517001310: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 32843107663: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 6764066317: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 2400931417: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 7019175469: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 5716870213: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1714992794: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 5313473264: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 2517683410: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 27360753694: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 6982904397: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 6760105601: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 2277203467: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1094421117: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 11900442433: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 8085061780: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 26995841333: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 7673085317: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 10959245375: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 8333404261: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1487463059: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 20440106944: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 7546791562: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 30520082704: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 25159901277: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 2789540554: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 6137325052: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 1319554203: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 2729844179: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1005840471: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1904575679: Zero precision/recall (n_rec_k=0, n_rel=2)
# User 8052565520: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 8022221754: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 9021537153: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 6559113057: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 9220880422: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 23907381557: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1116795070: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 2287933988: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1506434350: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 10301495806: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 12022503690: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 7490043540: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 5453837589: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1885453336: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1909041148: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 6013341201: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 11158241887: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 6251852735: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 5355295404: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 6204027023: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 8889359135: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1853823116: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 2546681659: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 2161360700: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 8050994162: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 8274658691: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 1666433122: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 2158518461: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 2123874937: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 5603138485: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 1637936710: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 5069912549: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 5033183440: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 12011921904: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 11838391370: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1434100797: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 21885784301: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 9875028943: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 28088474126: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 8765858496: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 21102757110: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 2273904631: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 8429283351: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 6917134989: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 2129300210: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 10703356078: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 7086202969: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 6236390023: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 42379428314: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 2790486791: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 28899228692: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 12509145843: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1861572183: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 9612584403: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1044261320: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 9197288172: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 2454983830: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 10061927643: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 32892650110: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 6678163527: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 8119483647: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 5400833641: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 5219149568: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 2852494524: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1172781871: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 5069901100: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 7591743858: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 8680478086: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 5432133251: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 24571915717: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 2400656638: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 5871382819: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 1907972074: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 35460383805: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 32951788183: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 11741501722: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 29678548993: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 5968454955: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 5104408918: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 799970294: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1299070458: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 26693936585: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 5382742012: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 26782915435: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 5278522133: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 984229622: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1309272082: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 11628645339: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 6660113098: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 20724380486: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 9915596483: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 2844290704: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 2518454631: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 12819843639: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1140305361: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 7538008549: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 24102615502: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 2062971381: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1759440296: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 6950984896: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1511259157: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 8815914426: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1376924250: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 5592688901: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 22837191334: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 23169938561: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 5791253018: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 25459134209: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 2060430795: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 6807482556: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 1466193104: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 6149846490: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 5672636824: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 6691820545: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 1864232104: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1705843321: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 26443100803: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1240856735: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1228287196: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 1184722073: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 32395108517: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 10151150526: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1336271823: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 5726337410: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 5136056795: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 9614744621: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 8523182271: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 411867282: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 2427631748: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 1186430192: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 8886647025: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 2714070005: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 2048139545: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 27904526431: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 10481814147: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1803892683: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 22038740311: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 901334103: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 2334961838: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 7183970720: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 8183775022: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 2517238370: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 5024024175: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 2138723354: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 2030097793: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 2382203342: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 2632112393: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 6209504550: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 2367743822: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 1845541839: Zero precision/recall (n_rec_k=1, n_rel=0)
# User 1289280337: Zero precision/recall (n_rec_k=0, n_rel=1)
# User 968450924: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 6812082432: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 11084448617: Zero precision/recall (n_rec_k=0, n_rel=0)
# User 6079083724: Zero precision/recall (n_rec_k=0, n_rel=0)

# %%
# Print evaluation metrics
print("\nSVD Evaluation Metrics:")
print(f"RMSE: {svd_rmse:.3f}")
print(f"MAE: {svd_mae:.3f}")
print(f"MSE: {svd_mse:.3f}")
print(f"Accuracy: {svd_accuracy:.3f}")
print(f"Precision@5: {svd_prec:.3f}")
print(f"Recall@5: {svd_rec:.3f}")
print(f"F1@5: {svd_f1:.3f}")
# Out:
# SVD Evaluation Metrics:
# RMSE: 0.852
# MAE: 0.575
# MSE: 0.725
# Accuracy: 0.597
# Precision@5: 0.817
# Recall@5: 0.888
# F1@5: 0.851

# %%
# User profile and top-N recommendations
def get_user_profile_and_recommendations(model, trainset, user_id, n, df, filter_by_favorite_brands=False):
    try:
        # Check if user is new (no ratings)
        user_data = df[df['author_id'] == user_id]
        is_new_user = len(user_data) == 0
        
        # User profile
        if is_new_user:
            total_reviews = 0
            avg_rating = 0.00
            skin_type = "Unknown"
            favorite_brands = []  # Empty for new users
        else:
            total_reviews = len(user_data)
            avg_rating = user_data['rating'].mean()
            skin_type = user_data['skin_type'].mode().iloc[0] if not user_data['skin_type'].isna().all() else "unknown"
            favorite_brands = user_data['brand_name'].value_counts().head(3).index.tolist()
        
        # Recommendations
        if is_new_user:
            # For new user, recommend top-N items by average rating
            item_ratings = df.groupby('product_id')['rating'].agg(['mean', 'count']).reset_index()
            item_ratings = item_ratings[item_ratings['count'] >= min_product_reviews]
            top_items = item_ratings.sort_values(by='mean', ascending=False).head(n)
            rec_df = top_items[['product_id', 'mean']].rename(columns={'mean': 'predicted_rating'})
            rec_df = rec_df.merge(
                df[['product_id', 'brand_name', 'product_name', 'price_usd', 'secondary_category', 'tertiary_category']].drop_duplicates(),
                on='product_id',
                how='left'
            )
        else:
            # For existing user, use SVD predictions
            inner_uid = trainset.to_inner_uid(user_id)
            all_items = set(trainset.all_items())
            rated_items = set(iid for (iid, _) in trainset.ur[inner_uid])
            unrated_items = [trainset.to_raw_iid(iid) for iid in all_items - rated_items]
            
            if not unrated_items:
                raise ValueError(f"No unrated items available for user {user_id}.")
            
            preds = [model.predict(user_id, iid) for iid in unrated_items]
            top_n = sorted(preds, key=lambda x: x.est, reverse=True)[:max(n * 2, 10)]
            recommendations = [(pred.iid, pred.est) for pred in top_n]
            rec_df = pd.DataFrame(recommendations, columns=['product_id', 'predicted_rating'])
            rec_df = rec_df.merge(
                df[['product_id', 'brand_name', 'product_name', 'price_usd', 'secondary_category', 'tertiary_category']].drop_duplicates(),
                on='product_id',
                how='left'
            )
        
        # Filter by favorite brands if requested and user is not new
        if filter_by_favorite_brands and favorite_brands and not is_new_user:
            rec_df = rec_df[rec_df['brand_name'].isin(favorite_brands)]
        rec_df = rec_df.head(n)
        
        rec_df['predicted_rating'] = rec_df['predicted_rating'].clip(1, 5).round(1)
        rec_df['price_usd'] = rec_df['price_usd'].round(1)
        
        # Format output
        print(f"\nTesting SVD:\n")
        print(f"👤 USER PROFILE: {user_id}")
        print("=" * 50)
        print(f"📊 Total Reviews: {total_reviews}")
        print(f"⭐ Average Rating Given: {avg_rating:.2f}" if not is_new_user else "⭐ Average Rating Given: N/A")
        print(f"🧴 Skin Type: {skin_type}")
        print(f"❤️ Favorite Brands: {', '.join(favorite_brands) if favorite_brands else 'None'}")
        print(f"\n🔍 Finding recommendations for user: {user_id}")
        print(f"📊 User has rated {total_reviews} products")
        print(f"\nTop-{n} Recommendations for User ID: {user_id} (SVD model)")
        if not rec_df.empty:
            print(rec_df[['brand_name', 'product_name', 'price_usd', 'secondary_category', 'tertiary_category', 'predicted_rating']].to_string(index=False))
        else:
            print(f"No recommendations generated for user {user_id}. Check if products are available after filtering.")
        
        return rec_df
    except ValueError as e:
        print(f"Error: {e}")
        return pd.DataFrame(columns=['product_id', 'brand_name', 'product_name', 'price_usd', 'secondary_category', 'tertiary_category', 'predicted_rating'])

# Test with new user ID and top-N
# sample_user = 'new_user'
top_n = 5
# get_user_profile_and_recommendations(best_svd, trainset, sample_user, top_n, df, filter_by_favorite_brands=False)
# Test with existing user for comparison
get_user_profile_and_recommendations(best_svd, trainset, '1238130325', top_n, df, filter_by_favorite_brands=True)
# Out:
# Testing SVD:
#
# 👤 USER PROFILE: 1238130325
# ==================================================
# 📊 Total Reviews: 12
# ⭐ Average Rating Given: 4.42
# 🧴 Skin Type: dry
# ❤️ Favorite Brands: The INKEY List, SEPHORA COLLECTION, CLINIQUE
#
# 🔍 Finding recommendations for user: 1238130325
# 📊 User has rated 12 products
#
# Top-5 Recommendations for User ID: 1238130325 (SVD model)
# No recommendations generated for user 1238130325. Check if products are available after filtering.
# Empty DataFrame
# Columns: [product_id, predicted_rating, brand_name, product_name, price_usd, secondary_category, tertiary_category]
# Index: []

# %% [markdown]
# ## Hybrid - Tan Yen Fang

# %% [markdown]
# ### Content-Based

# %%
# ----------------------------
# 3. Clean review text
# ----------------------------
def clean_text(text):
    text = str(text).lower()
    text = re.sub(r"[^a-z\s]", "", text)   # remove special characters
    text = re.sub(r"\s+", " ", text).strip()
    return text

merged_reviews_df["cleaned_review_text"] = merged_reviews_df["review_text"].apply(clean_text)

# ----------------------------
# 4. Add combined features to products
# ----------------------------
skincare_products_df["combined_features"] = (
    skincare_products_df["brand_name"].fillna("") + " " +
    skincare_products_df["tertiary_category"].fillna("") + " " +
    skincare_products_df["product_name"].fillna("") + " " +
    skincare_products_df.get("ingredients", pd.Series("")).fillna("") + " " +
    skincare_products_df.get("highlights", pd.Series("")).fillna("") + " " 
)


# ----------------------------
# 5. Merge reviews with product info
# ----------------------------
merged_reviews_df = merged_reviews_df.drop(columns=["brand_name", "product_name"], errors="ignore")

combined_df = pd.merge(
    merged_reviews_df,
    skincare_products_df[["product_id", "brand_name", "product_name", "combined_features"]],
    on="product_id",
    how="inner"
)

# ----------------------------
# 6. Sentiment analysis
# ----------------------------
def analyze_sentiment(text):
    if pd.isna(text) or not isinstance(text, str):
        return 0.0
    return TextBlob(text).sentiment.polarity

combined_df["sentiment_score"] = combined_df["cleaned_review_text"].apply(analyze_sentiment)

# ----------------------------
# 7. Train/test split
# ----------------------------
train_df, test_df = train_test_split(
    combined_df,
    test_size=0.2,
    random_state=42
)

# ----------------------------
# 8. Save final datasets
# ----------------------------
try:
    combined_df.to_csv("data/CleanedDataSet/combined_skincare_with_sentiment.csv", index=False)
    print("Combined dataset saved successfully")
except PermissionError:
    print("Could not save combined dataset CSV (file may be open)")

try:
    train_df.to_csv("data/CleanedDataSet/train_skincare.csv", index=False)
    test_df.to_csv("data/CleanedDataSet/test_skincare.csv", index=False)
    print("Train/test datasets saved successfully")
except PermissionError:
    print("Could not save train/test CSV files (files may be open)")

print("Full preprocessing and train/test split completed!")
print(f"Combined dataframe shape: {combined_df.shape}")
print(f"Train shape: {train_df.shape}, Test shape: {test_df.shape}")

# %%
import os
import numpy as np
import pandas as pd
from gensim.models import Word2Vec
from nltk.tokenize import word_tokenize
import nltk
import joblib
import matplotlib.pyplot as plt

nltk.download("punkt", quiet=True)

# Paths
TRAIN_PATH = "data/CleanedDataSet/train_skincare.csv"
MODEL_DIR = "models"
MODEL_PATH = os.path.join(MODEL_DIR, "word2vec_skincare.model")
EMBEDDINGS_PATH = os.path.join(MODEL_DIR, "product_embeddings.pkl")

# ---------------- 1) Load dataset ----------------
def load_dataset(path):
    df = pd.read_csv(path, low_memory=False)
    df = df.dropna(subset=["combined_features"]).copy()
    df["tokens"] = df["combined_features"].astype(str).str.lower().apply(word_tokenize)
    return df

# ---------------- 2) Extract tertiary category ----------------
def extract_tertiary(feature_str):
    """
    从 combined_features extract tertiary category
    """
    feature_str = str(feature_str).lower()
    
    mapping = {
        'moisturizer': 'Moisturizers',
        'serum': 'Face Serums',
        'eye cream': 'Eye Creams & Treatments',
        'treatment': 'Blemish & Acne Treatments',
        'lip balm': 'Lip Balms & Treatments',
        'sunscreen': 'Face Sunscreen',
        'cleanser': 'Face Wash & Cleansers',
        'face wash': 'Face Wash & Cleansers',
        'oil': 'Face Oils',
        'toner': 'Toners',
        'mask': 'Face Masks',
        'peel': 'Facial Peels',
        'exfoliator': 'Exfoliators',
        'eye mask': 'Eye Masks',
        'wipe': 'Face Wipes',
        'night cream': 'Night Creams',
        'mist': 'Mists & Essences',
        'essence': 'Mists & Essences',
        'sheet mask': 'Sheet Masks',
        'makeup remover': 'Makeup Removers'
    }
    
    for k, v in mapping.items():
        if k in feature_str:
            return v
    return 'Other'

# ---------------- 3) Train Word2Vec ----------------
def train_w2v(token_lists, model_path=MODEL_PATH):
    os.makedirs(os.path.dirname(model_path), exist_ok=True)
    model = Word2Vec(
        sentences=token_lists,
        vector_size=100,
        window=5,
        min_count=2,
        workers=4,
        sg=1,       # Skip-gram
        epochs= 80
    )
    model.save(model_path)
    print(f"Word2Vec model saved at: {model_path}")
    return model

# ---------------- 4) Build embeddings ----------------
def sentence_vec(tokens, model):
    vecs = [model.wv[t] for t in tokens if t in model.wv]
    return np.mean(vecs, axis=0) if vecs else np.zeros(model.vector_size)

def build_embeddings(df, model):
    # 确保 df 已经有 tertiary_category
    if 'tertiary_category' not in df.columns:
        df['tertiary_category'] = df['combined_features'].astype(str).apply(extract_tertiary)

    prod = df.groupby("product_id", as_index=False).agg({
        "brand_name": "first",
        "product_name": "first",
        "price_usd": "first",
        "tokens": "first",
        "tertiary_category": "first"
    })

    prod["embedding"] = prod["tokens"].apply(lambda toks: sentence_vec(toks, model))
    emb = np.vstack(prod["embedding"].values)
    return prod, emb

# ---------------- 5) Save embeddings ----------------
def save_embeddings(prod_df, prod_embeds, path=EMBEDDINGS_PATH):
    os.makedirs(os.path.dirname(path), exist_ok=True)
    joblib.dump((prod_df, prod_embeds), path)
    print(f"Embeddings saved at: {path}")

# ---------------- 6) Run pipeline ----------------
if __name__ == "__main__":
    df = load_dataset(TRAIN_PATH)
    df['tertiary_category'] = df['combined_features'].astype(str).apply(extract_tertiary)

    w2v = train_w2v(df["tokens"].tolist())
    prod_df, prod_embeds = build_embeddings(df, w2v)
    save_embeddings(prod_df, prod_embeds)

    print(f"{len(prod_df)} unique products embedded successfully")

# %%
import numpy as np
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity

# Recommendation function: content-based + same tertiary category
def recommend_same_category(prod_df, prod_embeds, product_id, top_n=10):
    # get targeted product
    target = prod_df[prod_df["product_id"] == product_id]
    if target.empty:
        raise ValueError(f"Product ID {product_id} not found.")
    
    # extract tertiary category
    tc = target["tertiary_category"].values[0] if "tertiary_category" in target else None
    if tc is None:
        raise ValueError(f"Product ID {product_id} has no tertiary_category information.")

    # Only select the product that same tertiary category
    candidates = prod_df[prod_df["tertiary_category"] == tc]
    
    # 如果只有目标产品本身，直接返回空
    if len(candidates) <= 1:
        return pd.DataFrame(columns=[
            "product_id", "brand_name", "product_name", "price_usd", "tertiary_category", "similarity_score"
        ])
    
    # 计算相似度
    target_vec = target["embedding"].values[0].reshape(1, -1)
    cand_embeds = np.vstack(candidates["embedding"].values)
    sims = cosine_similarity(target_vec, cand_embeds)[0]

    # Build DataFrame
    recs = candidates.copy()
    recs["similarity_score"] = sims
    recs = recs[recs["product_id"] != product_id].sort_values("similarity_score", ascending=False)
    
    return recs.head(top_n)[[
        "product_id", "brand_name", "product_name", "price_usd", "tertiary_category", "similarity_score"
    ]]

# -------- Example usage --------
recs = recommend_same_category(prod_df, prod_embeds, product_id="P454095", top_n=5)
print(recs)

# %% [markdown]
# ### Surpris SVD

# %%
import pandas as pd
import numpy as np
from collections import defaultdict
from surprise import Dataset, Reader, SVD, accuracy, dump
from surprise.model_selection import train_test_split
import os

print("Using Surprise-based collaborative filtering...")

# ---------------- 1) Load data ----------------
df = pd.read_csv("data/CleanedDataSet/combined_skincare_with_sentiment.csv", low_memory=False)

print(f"Data loaded: {df.shape}")
print("Columns available:", df.columns.tolist())

# ---------------- 2) Prepare final rating ----------------
if "sentiment_score" in df.columns:
    # Normalize sentiment_score (-1 to 1) → (0 to 5)
    df["sentiment_normalized"] = (df["sentiment_score"] + 1) * 2.5
    df["final_rating"] = 0.7 * df["rating"] + 0.3 * df["sentiment_normalized"]
else:
    df["final_rating"] = df["rating"]

print(f"Final rating range: {df['final_rating'].min():.2f} to {df['final_rating'].max():.2f}")

# ---------------- 3) Build Surprise dataset ----------------
reader = Reader(rating_scale=(1, 5))
data = Dataset.load_from_df(df[["author_id", "product_id", "final_rating"]], reader)

# ---------------- 4) Train-test split ----------------
trainset, testset = train_test_split(data, test_size=0.2, random_state=42)

# ---------------- 5) Train SVD model ----------------
print("Training Surprise SVD model...")
model = SVD(
    n_factors=50,   # latent dimensions
    lr_all=0.005,   # learning rate
    reg_all=0.02,   # regularization
    random_state=42
)
model.fit(trainset)

# ---------------- 6) Save Model ----------------
print("Saving model...")
model_path = "models/surprise_svd_model.pkl"
# Create directory if not exists
os.makedirs(os.path.dirname(model_path), exist_ok=True)
dump.dump(model_path, algo=model)
print(f"✅ Model saved to {model_path}")

# ---------------- 7) Evaluate with RMSE ----------------
predictions = model.test(testset)
rmse = accuracy.rmse(predictions)
print(f"✅ Model evaluation completed. Test RMSE: {rmse:.4f}")

# ---------------- 8) Top-N helper functions ----------------
def get_top_n(predictions, n=10):
    """Return the top-N recommendation for each user from a set of predictions."""
    top_n = defaultdict(list)
    for uid, iid, true_r, est, _ in predictions:
        top_n[uid].append((iid, est))

    # sort and get top N
    for uid, user_ratings in top_n.items():
        user_ratings.sort(key=lambda x: x[1], reverse=True)
        top_n[uid] = user_ratings[:n]
    return top_n

def precision_recall_f1_coverage(predictions, n=10, threshold=3.5):
    """
    Compute precision, recall, F1 and coverage at Top-N recommendations.
    threshold: rating above this is considered relevant.
    """
    top_n = get_top_n(predictions, n=n)

    precisions = []
    recalls = []
    all_recommended_items = set()

    for uid, user_ratings in top_n.items():
        # Relevant items for this user (ground truth)
        true_items = {iid for (uid_, iid, true_r, est, _) in predictions if uid_ == uid and true_r >= threshold}
        recommended_items = {iid for (iid, est) in user_ratings}

        all_recommended_items.update(recommended_items)

        n_rel = len(true_items)  # relevant
        n_rec_k = len(recommended_items)  # recommended in top N
        n_rel_and_rec_k = len(true_items & recommended_items)

        if n_rec_k > 0:
            precisions.append(n_rel_and_rec_k / n_rec_k)
        if n_rel > 0:
            recalls.append(n_rel_and_rec_k / n_rel)

    precision = np.mean(precisions) if precisions else 0
    recall = np.mean(recalls) if recalls else 0
    f1 = (2 * precision * recall / (precision + recall)) if (precision + recall) > 0 else 0

    # Coverage = proportion of unique items ever recommended
    all_items = {iid for (_, iid, _, _, _) in predictions}
    coverage = len(all_recommended_items) / len(all_items)

    return precision, recall, f1, coverage

# ---------------- 9) Compute evaluation metrics ----------------
precision, recall, f1, coverage = precision_recall_f1_coverage(predictions, n=5, threshold=3.5)

print("\n📊 Evaluation Metrics (Top-5):")
print(f"   Precision: {precision:.4f}")
print(f"   Recall:    {recall:.4f}")
print(f"   F1-score:  {f1:.4f}")
print(f"   Coverage:  {coverage:.4f}")

# ---------------- 10) Cold Start Helper Functions ----------------
def get_popular_products(df, top_n=10, min_ratings=5):
    """Get popular products for cold start fallback"""
    product_stats = df.groupby('product_id').agg({
        'final_rating': ['count', 'mean']
    }).round(2)
    product_stats.columns = ['rating_count', 'avg_rating']
    product_stats = product_stats.reset_index()
    
    # Filter products with enough ratings
    qualified = product_stats[product_stats['rating_count'] >= min_ratings]
    qualified = qualified.sort_values(['rating_count', 'avg_rating'], ascending=False)
    
    return qualified.head(top_n)

def format_popular_recommendations(popular_products, df):
    """Format popular products recommendations"""
    product_info = df[['product_id', 'product_name', 'brand_name']].drop_duplicates()
    result = pd.merge(popular_products, product_info, on='product_id')
    
    print("\n🔥 Popular Products (Cold Start Fallback):")
    print("-" * 60)
    recommendations = []
    
    for i, row in result.iterrows():
        print(f"{i+1}. {row['product_name']}")
        print(f"   Brand: {row['brand_name']}")
        print(f"   Avg Rating: {row['avg_rating']} ({row['rating_count']} ratings)")
        print()
        recommendations.append((row['product_id'], row['avg_rating']))
    
    return recommendations

# ---------------- 11) Recommend Product for existing user ----------------
def recommend_products_surprise(user_id, df, model, top_n=5):
    """Recommend top N products for existing users only (no cold start)"""
    user_id = str(user_id)

    # Ensure user exists in dataset
    if user_id not in df["author_id"].values:
        raise ValueError(f"User {user_id} not found in dataset. SVD handles only existing users.")

    # Get all unique products and those the user has already rated
    all_products = df["product_id"].unique()
    user_products = df[df["author_id"] == user_id]["product_id"].unique()

    predictions = []
    for product_id in all_products:
        if product_id not in user_products:
            try:
                pred = model.predict(user_id, str(product_id))
                predictions.append((product_id, pred.est))
            except:
                continue  # skip if prediction fails

    # Sort by predicted rating
    top_predictions = sorted(predictions, key=lambda x: x[1], reverse=True)[:top_n]

    # Get product details
    product_info = df.drop_duplicates("product_id")[["product_id", "product_name", "brand_name"]]

    print(f"\n🎯 Top {top_n} Recommendations for Existing User {user_id}:")
    print("-" * 60)
    for i, (product_id, predicted_rating) in enumerate(top_predictions, 1):
        product_row = product_info[product_info["product_id"] == product_id]
        if not product_row.empty:
            name = product_row["product_name"].values[0]
            brand = product_row["brand_name"].values[0]
            print(f"{i}. {name}")
            print(f"   Brand: {brand}")
            print(f"   Predicted Rating: {predicted_rating:.2f}")
        else:
            print(f"{i}. Product {product_id} - Details not available")

    return top_predictions
# ---------------- 12) Test recommendation with both existing and new user ----------------
if len(df["author_id"].unique()) > 0:
    # Test with existing user
    sample_user = df["author_id"].iloc[0]
    print("Testing with existing user:")
    recs = recommend_products_surprise(sample_user, df, model, top_n=5)
    
    # Test with new user (cold start)
    print("\n" + "="*60)
    print("Testing Cold Start with new user:")
    new_user = "new_user_12345"
    new_user_recs = recommend_products_surprise(new_user, df, model, top_n=5)
else:
    print("No users found in dataset")

# %% [markdown]
# ### Final Hybrid

# %% [markdown]
# #### User Categories & Weight Allocation:
# | User Type | Content Weight | Collaborative Weight | Rationale |
# |-----------|----------------|---------------------|-----------|
# |  **New User** | 70% | 30% | Heavy content-based for cold-start scenario |
# |  **Existing User** | 60% | 40% | Balanced approach with some history |
# |  **Experienced User** | 40% | 60% | Leverage collaborative patterns |
#
# #### User Classification:
# - **New Users**: Users who exist ONLY in test data (true cold-start scenario)
# - **Few Ratings Users**: Users with 1-9 ratings in training data
# - **Experienced Users**: Users with 10+ ratings in training data
#
# #### Progressive Strategy Logic:
# 1. **Cold-start** → Rely more on product features (content-based)
# 2. **Building history** → Gradually incorporate user similarities
# 3. **Rich history** → Leverage collaborative filtering patterns
#
# ### Objective
# Validate that this intuitive progressive weighting strategy performs optimally across all user types with comprehensive evaluation metrics.
#
# ### Metrics Evaluated:
# - **RMSE** (Root Mean Square Error) - Prediction accuracy
# - **Accuracy** - Percentage of correctly classified ratings (≥4 as positive)
# - **Coverage** - Percentage of unique products that can be recommended
# - **F1-Score** - Harmonic mean of precision and recall
# - **Precision** - True positives / (True positives + False positives)
# - **Recall** - True positives / (True positives + False negatives)

# %%
# ====================================================================
# HYBRID.IPYNB - HYBRID RECOMMENDER EVALUATION & TESTING
# ====================================================================
# This notebook is for testing and evaluating the hybrid recommender system
# The actual implementation is in utils/recommender.py

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
from math import sqrt
from tqdm import tqdm
import warnings
warnings.filterwarnings('ignore')

# Import the actual recommender implementation
from utils.recommender import EnhancedHybridRecommender

print("📚 Libraries imported successfully!")
print("🎯 Ready to test and evaluate the Enhanced Hybrid Recommender System")
print("=" * 60)
# Out:
# 📚 Libraries imported successfully!
# 🎯 Ready to test and evaluate the Enhanced Hybrid Recommender System
# ============================================================

# %%
# ====================================
#  INITIALIZE HYBRID RECOMMENDER 
# ====================================

print("Initializing Hybrid Recommender System...")
print("=" * 60)

# File paths - CORRECTED TO USE PROPER TRAIN/TEST SPLIT
TRAIN_PATH = "data/CleanedDataSet/train_skincare.csv"        # Training data ONLY
TEST_PATH = "data/CleanedDataSet/test_skincare.csv"          # Test data for evaluation
PRODUCTS_PATH = "data/CleanedDataSet/filtered_skincare_products.csv"
CONTENT_MODEL_PATH = "models/product_embeddings.pkl"
SVD_MODEL_PATH = "models/surprise_svd_model.pkl"

print("📊 USING PROPER TRAIN/TEST SPLIT:")
print(f"   Training: {TRAIN_PATH}")
print(f"   Testing:  {TEST_PATH}")

# Initialize the recommender system with TRAINING data only
try:
    recommender = EnhancedHybridRecommender(
        train_path=TRAIN_PATH,              # Only training data
        products_path=PRODUCTS_PATH,
        content_model_path=CONTENT_MODEL_PATH,
        svd_model_path=SVD_MODEL_PATH
    )
    
    print("✅ Recommender system initialized successfully!")
    
    # Load test dataset for proper evaluation
    print("📊 Loading test dataset for evaluation...")
    test_df = pd.read_csv(TEST_PATH)
    print(f"✅ Test dataset loaded: {len(test_df):,} test samples")
    
    # Display system statistics
    print("\nSystem Statistics:")
    print(f"   • Products in catalog: {len(recommender.prod_df):,}")
    print(f"   • Training data: {len(recommender.train_df):,} ratings")
    print(f"   • Test data: {len(test_df):,} ratings")
    print(f"   • Users in system: {len(recommender.user_history_cache):,}")
    print(f"   • Global average rating: {recommender.global_avg:.3f}")
    
    # Verify proper separation
    print(f"\n🔍 TRAIN/TEST VERIFICATION:")
    print(f"   • Train + Test = {len(recommender.train_df) + len(test_df):,} total ratings")
    print(f"   • Proper separation: ✅ No data leakage!")
    
    # Make test_df globally available for evaluation functions
    globals()['test_df'] = test_df
    
except Exception as e:
    print(f"❌ Error initializing recommender: {e}")
    print("\nMake sure:")
    print("   1. All data files exist in the correct paths")
    print("   2. Models are trained and saved")
    print("   3. utils/recommender.py contains EnhancedHybridRecommender class")
    raise
# Out:
# Initializing Hybrid Recommender System...
# ============================================================
# 📊 USING PROPER TRAIN/TEST SPLIT:
#    Training: data/CleanedDataSet/train_skincare.csv
#    Testing:  data/CleanedDataSet/test_skincare.csv
# HybridRecommender LOADED!
# ✅ Recommender system initialized successfully!
# 📊 Loading test dataset for evaluation...
# ✅ Test dataset loaded: 160,291 test samples
#
# System Statistics:
#    • Products in catalog: 1,803
#    • Training data: 641,164 ratings
#    • Test data: 160,291 ratings
#    • Users in system: 347,100
#    • Global average rating: 3.934
#
# 🔍 TRAIN/TEST VERIFICATION:
#    • Train + Test = 801,455 total ratings
#    • Proper separation: ✅ No data leakage!

# %%
# ====================================================================
# � SYSTEM STATUS CHECK - VERIFY RECOMMENDER CONFIGURATION
# ====================================================================

print("� SYSTEM STATUS CHECK")
print("=" * 50)

if 'recommender' in globals():
    print(f"✅ Recommender Status: LOADED")
    print(f"📂 Training Data: {recommender.train_path}")
    print(f"📊 Training Samples: {len(recommender.train_df):,}")
    print(f"🎯 Users in System: {len(recommender.user_history_cache):,}")
    print(f"🛍️  Products in Catalog: {len(recommender.prod_df):,}")
    print(f"⭐ Global Average Rating: {recommender.global_avg:.3f}")
    
    # Quick data integrity check
    if "train_skincare" in recommender.train_path:
        print(f"\n✅ Data Split: PROPER (using training split only)")
        print(f"🎯 Configuration: READY FOR EVALUATION")
    elif "combined_skincare" in recommender.train_path:
        print(f"\n⚠️  Data Split: FULL DATASET (potential data leakage)")
        print(f"🔧 Recommendation: Re-initialize with proper train/test split")
    else:
        print(f"\n📝 Data Split: CUSTOM ({recommender.train_path})")
        
    # Test data check
    if 'test_df' in globals():
        print(f"📋 Test Data: {len(test_df):,} samples")
    else:
        print(f"❌ Test Data: NOT LOADED")
        
else:
    print("❌ Recommender Status: NOT LOADED")
    print("🔧 Run the initialization cell to load the recommender")
    
print(f"\n📋 Current Paths:")
if 'TRAIN_PATH' in globals():
    print(f"   🚂 TRAIN_PATH: {TRAIN_PATH}")
if 'TEST_PATH' in globals():
    print(f"   🧪 TEST_PATH: {TEST_PATH}")

print("=" * 50)
# Out:
# � SYSTEM STATUS CHECK
# ==================================================
# ✅ Recommender Status: LOADED
# 📂 Training Data: data/CleanedDataSet/train_skincare.csv
# 📊 Training Samples: 641,164
# 🎯 Users in System: 347,100
# 🛍️  Products in Catalog: 1,803
# ⭐ Global Average Rating: 3.934
#
# ✅ Data Split: PROPER (using training split only)
# 🎯 Configuration: READY FOR EVALUATION
# 📋 Test Data: 160,291 samples
#
# 📋 Current Paths:
#    🚂 TRAIN_PATH: data/CleanedDataSet/train_skincare.csv
#    🧪 TEST_PATH: data/CleanedDataSet/test_skincare.csv
# ==================================================

# %%
def evaluate_your_adaptive_strategy(recommender, sample_size=None):
    """
    Evaluate your original adaptive weight strategy:
    - New Users (test-only): 70% Content, 30% Collaborative
    - Few Ratings: 60% Content, 40% Collaborative  
    - Experienced: 40% Content, 60% Collaborative
    
    Args:
        sample_size: Number of users to sample per category (None = use all users)
    """
    from sklearn.metrics import mean_squared_error, mean_absolute_error, f1_score, precision_score, recall_score, accuracy_score
    import numpy as np
    import pandas as pd
    import random
    
    print("🎯 EVALUATING YOUR ADAPTIVE WEIGHT STRATEGY")
    print("=" * 60)
    
    # Define weight strategy
    your_strategy = {
        'New Users': {
            'content_weight': 0.7,
            'collab_weight': 0.3,
            'description': '70% Content + 30% Collaborative'
        },
        'Few Ratings': {
            'content_weight': 0.6,
            'collab_weight': 0.4, 
            'description': '60% Content + 40% Collaborative'
        },
        'Experienced': {
            'content_weight': 0.4,
            'collab_weight': 0.6,
            'description': '40% Content + 60% Collaborative'
        }
    }
    
    results = []
    
    # 1. NEW USERS - Test-only users (true cold-start)
    train_users = set(recommender.train_df['author_id'].unique())
    test_users = set(test_df['author_id'].unique())
    new_users = list(test_users - train_users)  # Users ONLY in test
    user_rating_counts = recommender.train_df['author_id'].value_counts()
    
    print(f"Found {len(new_users):,} new users, {len(user_rating_counts):,} existing users")
    
    if len(new_users) > 0:
        sample_new = new_users if sample_size is None else random.sample(new_users, min(sample_size, len(new_users)))
        content_w = your_strategy['New Users']['content_weight']
        collab_w = your_strategy['New Users']['collab_weight']
        
        print(f"Evaluating {len(sample_new):,} new users...")
        predictions, actuals = [], []
        unique_products = set()
        
        for user_id in tqdm(sample_new, desc="Processing New Users", leave=False):
            user_test = test_df[test_df['author_id'] == user_id]
            user_sample = user_test.sample(n=min(3, len(user_test)))
            
            for _, row in user_sample.iterrows():
                try:
                    pred_result = recommender.hybrid_predict(
                        user_id, row['product_id'], content_w, collab_w
                    )
                    pred = pred_result[0] if isinstance(pred_result, tuple) else pred_result
                    
                    if pred > 0:
                        predictions.append(pred)
                        actuals.append(row['rating'])
                        unique_products.add(row['product_id'])
                except:
                    continue
        
        if len(predictions) >= 10:
            rmse = np.sqrt(mean_squared_error(actuals, predictions))
            mae = mean_absolute_error(actuals, predictions)
            
            binary_actual = [1 if r >= 4 else 0 for r in actuals]
            binary_pred = [1 if r >= 4 else 0 for r in predictions]
            
            accuracy = accuracy_score(binary_actual, binary_pred)
            f1 = f1_score(binary_actual, binary_pred, zero_division=0)
            precision = precision_score(binary_actual, binary_pred, zero_division=0)
            recall = recall_score(binary_actual, binary_pred, zero_division=0)
            coverage = len(unique_products) / len(test_df['product_id'].unique()) * 100
            
            results.append({
                'User_Type': 'New Users',
                'Strategy': your_strategy['New Users']['description'],
                'Content_Weight': content_w,
                'Collab_Weight': collab_w,
                'Sample_Size': len(sample_new),
                'Predictions': len(predictions),
                'RMSE': rmse,
                'MAE': mae,
                'Accuracy': accuracy,
                'F1_Score': f1,
                'Precision': precision,
                'Recall': recall,
                'Coverage_%': coverage
            })
    
    # 2. FEW RATINGS USERS (1-9 ratings)
    few_users = [u for u in user_rating_counts.index 
                 if 1 <= user_rating_counts[u] <= 9 and u in test_users]
    
    if len(few_users) > 0:
        sample_few = few_users if sample_size is None else random.sample(few_users, min(sample_size, len(few_users)))
        content_w = your_strategy['Few Ratings']['content_weight']
        collab_w = your_strategy['Few Ratings']['collab_weight']
        
        print(f"Evaluating {len(sample_few):,} few-rating users...")
        predictions, actuals = [], []
        unique_products = set()
        
        for user_id in tqdm(sample_few, desc="Processing Few-Rating Users", leave=False):
            user_test = test_df[test_df['author_id'] == user_id]
            user_sample = user_test.sample(n=min(3, len(user_test)))
            
            for _, row in user_sample.iterrows():
                try:
                    pred_result = recommender.hybrid_predict(
                        user_id, row['product_id'], content_w, collab_w
                    )
                    pred = pred_result[0] if isinstance(pred_result, tuple) else pred_result
                    
                    if pred > 0:
                        predictions.append(pred)
                        actuals.append(row['rating'])
                        unique_products.add(row['product_id'])
                except:
                    continue
        
        if len(predictions) >= 10:
            rmse = np.sqrt(mean_squared_error(actuals, predictions))
            mae = mean_absolute_error(actuals, predictions)
            
            binary_actual = [1 if r >= 4 else 0 for r in actuals]
            binary_pred = [1 if r >= 4 else 0 for r in predictions]
            
            accuracy = accuracy_score(binary_actual, binary_pred)
            f1 = f1_score(binary_actual, binary_pred, zero_division=0)
            precision = precision_score(binary_actual, binary_pred, zero_division=0)
            recall = recall_score(binary_actual, binary_pred, zero_division=0)
            coverage = len(unique_products) / len(test_df['product_id'].unique()) * 100
            
            results.append({
                'User_Type': 'Few Ratings',
                'Strategy': your_strategy['Few Ratings']['description'],
                'Content_Weight': content_w,
                'Collab_Weight': collab_w,
                'Sample_Size': len(sample_few),
                'Predictions': len(predictions),
                'RMSE': rmse,
                'MAE': mae,
                'Accuracy': accuracy,
                'F1_Score': f1,
                'Precision': precision,
                'Recall': recall,
                'Coverage_%': coverage
            })
    
    # 3. EXPERIENCED USERS (10+ ratings)
    exp_users = [u for u in user_rating_counts.index 
                 if user_rating_counts[u] >= 10 and u in test_users]
    
    if len(exp_users) > 0:
        sample_exp = exp_users if sample_size is None else random.sample(exp_users, min(sample_size, len(exp_users)))
        content_w = your_strategy['Experienced']['content_weight']
        collab_w = your_strategy['Experienced']['collab_weight']
        
        print(f"Evaluating {len(sample_exp):,} experienced users...")
        predictions, actuals = [], []
        unique_products = set()
        
        for user_id in tqdm(sample_exp, desc="Processing Experienced Users", leave=False):
            user_test = test_df[test_df['author_id'] == user_id]
            user_sample = user_test.sample(n=min(3, len(user_test)))
            
            for _, row in user_sample.iterrows():
                try:
                    pred_result = recommender.hybrid_predict(
                        user_id, row['product_id'], content_w, collab_w
                    )
                    pred = pred_result[0] if isinstance(pred_result, tuple) else pred_result
                    
                    if pred > 0:
                        predictions.append(pred)
                        actuals.append(row['rating'])
                        unique_products.add(row['product_id'])
                except:
                    continue
        
        if len(predictions) >= 10:
            rmse = np.sqrt(mean_squared_error(actuals, predictions))
            mae = mean_absolute_error(actuals, predictions)
            
            binary_actual = [1 if r >= 4 else 0 for r in actuals]
            binary_pred = [1 if r >= 4 else 0 for r in predictions]
            
            accuracy = accuracy_score(binary_actual, binary_pred)
            f1 = f1_score(binary_actual, binary_pred, zero_division=0)
            precision = precision_score(binary_actual, binary_pred, zero_division=0)
            recall = recall_score(binary_actual, binary_pred, zero_division=0)
            coverage = len(unique_products) / len(test_df['product_id'].unique()) * 100
            
            results.append({
                'User_Type': 'Experienced',
                'Strategy': your_strategy['Experienced']['description'],
                'Content_Weight': content_w,
                'Collab_Weight': collab_w,
                'Sample_Size': len(sample_exp),
                'Predictions': len(predictions),
                'RMSE': rmse,
                'MAE': mae,
                'Accuracy': accuracy,
                'F1_Score': f1,
                'Precision': precision,
                'Recall': recall,
                'Coverage_%': coverage
            })
    
    print("\\n✅ Evaluation completed for all user types!")
    print("\\n" + "=" * 60)
    return pd.DataFrame(results)

print("📊 Your adaptive strategy evaluation function ready!")
# Out:
# 📊 Your adaptive strategy evaluation function ready!

# %%
# ====================================================================
# 🚀 RUN EVALUATION OF YOUR ADAPTIVE STRATEGY (ALL USERS)
# ====================================================================

print("🎯 EVALUATING YOUR ORIGINAL ADAPTIVE WEIGHT APPROACH")
print("📋 Strategy:")
print("   • New Users: 70% Content + 30% Collaborative")
print("   • Few Ratings: 60% Content + 40% Collaborative")
print("   • Experienced: 40% Content + 60% Collaborative")
print("=" * 60)

# Run evaluation on ALL available users for most comprehensive results
print("⏱️  Running comprehensive evaluation on ALL users (this may take several minutes)...")
your_results = evaluate_your_adaptive_strategy(recommender, sample_size=None)  # None = use all users

# Display comprehensive results
if not your_results.empty:
    print("\n🎉 EVALUATION COMPLETED!")
    print("\n📊 COMPREHENSIVE RESULTS:")
    print("=" * 60)
    
    for _, row in your_results.iterrows():
        print(f"{row['User_Type'].upper()}:")
        print(f"   Strategy: {row['Strategy']}")
        print(f"   Sample Size: {row['Sample_Size']:,} users")
        print(f"   Predictions: {row['Predictions']:,}")
        print(f"   📈 RMSE: {row['RMSE']:.4f}")
        print(f"   📈 Accuracy: {row['Accuracy']:.4f} ({row['Accuracy']*100:.2f}%)")
        print(f"   📈 F1-Score: {row['F1_Score']:.4f}")
        print(f"   📈 Precision: {row['Precision']:.4f}")
        print(f"   📈 Recall: {row['Recall']:.4f}")
        print(f"   📈 Coverage: {row['Coverage_%']:.2f}%")
    
else:
    print("❌ Evaluation failed - no results generated")

print("\\n" + "=" * 60)
# Out:
# 🎯 EVALUATING YOUR ORIGINAL ADAPTIVE WEIGHT APPROACH
# 📋 Strategy:
#    • New Users: 70% Content + 30% Collaborative
#    • Few Ratings: 60% Content + 40% Collaborative
#    • Experienced: 40% Content + 60% Collaborative
# ============================================================
# ⏱️  Running comprehensive evaluation on ALL users (this may take several minutes)...
# 🎯 EVALUATING YOUR ADAPTIVE WEIGHT STRATEGY
# ============================================================
# Found 72,250 new users, 357,909 existing users
# Evaluating 72,250 new users...
# Evaluating 55,690 few-rating users...
# Evaluating 3,578 experienced users...
# \n✅ Evaluation completed for all user types!
# \n============================================================
#
# 🎉 EVALUATION COMPLETED!
#
# 📊 COMPREHENSIVE RESULTS:
# ============================================================
# NEW USERS:
#    Strategy: 70% Content + 30% Collaborative
#    Sample Size: 72,250 users
#    Predictions: 76,266
#    📈 RMSE: 1.0431
#    📈 Accuracy: 0.6795 (67.95%)
#    📈 F1-Score: 0.7608
#    📈 Precision: 0.9638
#    📈 Recall: 0.6284
#    📈 Coverage: 96.54%
# FEW RATINGS:
#    Strategy: 60% Content + 40% Collaborative
#    Sample Size: 55,690 users
#    Predictions: 69,081
#    📈 RMSE: 0.9688
#    📈 Accuracy: 0.7635 (76.35%)
#    📈 F1-Score: 0.8478
#    📈 Precision: 0.9042
#    📈 Recall: 0.7980
#    📈 Coverage: 94.72%
# EXPERIENCED:
#    Strategy: 40% Content + 60% Collaborative
#    Sample Size: 3,578 users
#    Predictions: 8,615
#    📈 RMSE: 0.7464
#    📈 Accuracy: 0.8865 (88.65%)
#    📈 F1-Score: 0.9352
#    📈 Precision: 0.9519
#    📈 Recall: 0.9192
#    📈 Coverage: 68.39%
# \n============================================================

# %%
# ====================================================================
# 🎯 HYBRID SYSTEM CORE EVALUATION METRICS
# ====================================================================

# Suppress warnings for this cell
import warnings
warnings.filterwarnings('ignore')

print("🎯 HYBRID RECOMMENDER SYSTEM - CORE METRICS")
print("=" * 55)

# Check if all required variables are defined
required_vars = ['overall_rmse', 'overall_accuracy', 'overall_f1', 
                'overall_precision', 'overall_recall', 'overall_coverage',
                'total_samples', 'total_predictions']

all_vars_defined = all(var in globals() and globals()[var] is not None for var in required_vars)

if all_vars_defined:
    print("📊 EVALUATION RESULTS:")
    print(f"   🔹 RMSE:      {overall_rmse:.4f}")
    print(f"   🔹 Accuracy:  {overall_accuracy:.4f} ({overall_accuracy*100:.2f}%)")
    print(f"   🔹 Precision: {overall_precision:.4f} ({overall_precision*100:.2f}%)")
    print(f"   🔹 Recall:    {overall_recall:.4f} ({overall_recall*100:.2f}%)")
    print(f"   🔹 F1-Score:  {overall_f1:.4f} ({overall_f1*100:.2f}%)")
    
    print(f"\n📋 SYSTEM OVERVIEW:")
    print(f"   • Total Users:      {total_samples:,}")
    print(f"   • Total Predictions: {total_predictions:,}")
    print(f"   • Coverage:         {overall_coverage:.2f}%")
    
    # Simple performance assessment
    print(f"\n🏆 PERFORMANCE ASSESSMENT:")
    if overall_f1 >= 0.8:
        print("   ✅ EXCELLENT performance (F1 ≥ 80%)")
    elif overall_f1 >= 0.7:
        print("   ✅ GOOD performance (F1 ≥ 70%)")
    elif overall_f1 >= 0.6:
        print("   ⚠️  FAIR performance (F1 ≥ 60%)")
    else:
        print("   ❌ NEEDS IMPROVEMENT (F1 < 60%)")

else:
    print("❌ System metrics not available.")
    print("💡 Please run the evaluation cells in order:")
    print("   1. Run the evaluation cell (cell 6)")
    print("   2. Run the metrics calculation cell (cell 7)")  
    print("   3. Then run this core metrics cell")
    
    # Show which variables are missing
    missing_vars = [var for var in required_vars if var not in globals() or globals()[var] is None]
    if missing_vars:
        print(f"   Missing variables: {', '.join(missing_vars)}")

print("=" * 55)
# Out:
# 🎯 HYBRID RECOMMENDER SYSTEM - CORE METRICS
# =======================================================
# ❌ System metrics not available.
# 💡 Please run the evaluation cells in order:
#    1. Run the evaluation cell (cell 6)
#    2. Run the metrics calculation cell (cell 7)
#    3. Then run this core metrics cell
#    Missing variables: overall_rmse, overall_accuracy, overall_f1, overall_precision, overall_recall, overall_coverage, total_samples, total_predictions
# =======================================================
